# %%
import random
import cobra
import escher
import pandas as pd
import numpy as np
import json
import csv
from cobra.io import save_json_model
from cobra import Reaction
from collections import Counter
from cobra.flux_analysis.loopless import add_loopless, loopless_solution

# %%
cobra.Configuration().solver = "cplex"

# %%
model_path = 'iMT1026v3.xml'
#model_path = 'iPichia.xml'

model = cobra.io.read_sbml_model(model_path)

model
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_oligoP_v "oligophosphate (5-P)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_polyP_v "polyphosphate (100-P)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_v "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_c "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_c "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_c "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_c "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_m "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppi_m "Diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h_m "H+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_m "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_allphn_c "Allophanate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_c "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nh4_c "Ammonium">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_x "H2O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_x "Oxygen">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_x "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tre_c "Trehalose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_D_c "D-Glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_e "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tre_e "Trehalose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_D_e "D-Glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tre_v "Trehalose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_D_v "D-Glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_thmpp_m "Thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pyr_m "Pyruvate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_co2_m "CO2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2_Hydroxyethyl_ThPP_m "2-(alpha-Hydroxyethyl)thiamine diphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o2_m "H2O2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_focytC_m "Ferrocytochrome C">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ficytC_m "Ferricytochrome c">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_akg_c "2-Oxoglutarate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gln_L_c "L-Glutamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fdxrd_c "Reduced ferredoxin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glu_L_c "L-Glutamate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fdxox_c "Oxidized ferredoxin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_glc_D_B_c "beta-D-Glucose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_malt_c "Maltose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_5aop_c "5-Aminolevulinate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ppbng_c "Porphobilinogen">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dmlz_c "6,7-Dimethyl-8-(1-D-ribityl)lumazine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_4r5au_c "4-(1-D-Ribitylamino)-5-aminouracil">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ribflv_c "Riboflavin">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_c "Oxygen">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe2_c "Fe2+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fe3_c "Fe3+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_o2_m "Oxygen">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_hmbil_c "Hydroxymethylbilane">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_c "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_c "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_r "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_r "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_r "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_r "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_g "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_h2o_g "H2O">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_g "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pi_g "Phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_m "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_m "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_camp_c "cAMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadh_c "NADH">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nad_c "NAD+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ncam_c "Nicotinamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adprib_c "ADP-ribose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nad_m "NAD+">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ncam_m "Nicotinamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adprib_m "ADP-ribose">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_c "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nmn_c "Nicotinamide D-ribonucleotide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_amp_m "AMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nmn_m "Nicotinamide D-ribonucleotide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadp_c "NADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadp_m "NADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadh_m "NADH">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadph_m "NADPH">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nadph_c "NADPH">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gthox_c "Oxidized glutathione">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gthrd_c "Reduced glutathione">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gthox_m "Oxidized glutathione">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_gthrd_m "Reduced glutathione">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ap4a_c "P1,P4-Bis(5'-adenosyl) tetraphosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dpcoa_c "Dephospho-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_coa_c "CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_dpcoa_m "Dephospho-CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_coa_m "CoA">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udp_c "UDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ump_c "UMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_utp_c "UTP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_atp_n "ATP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ump_n "UMP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_adp_n "ADP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_udp_n "UDP">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fad_c "FAD">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_fmn_c "FMN">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pydx5p_c "Pyridoxal 5'-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_pydx_c "Pyridoxal">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M
">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE3_26 "3-Hydroxyhexacosanoyl-CoA dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_14 "(2E)-tetradecanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_16 "(2E)-hexadecanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_18 "(2E)-octadecanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_20 "(2E)-Eicosanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_22 "(2E)-Docosanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_24 "(2E)-tetracosanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FAE4_26 "(2E)-hexacosanoyl-CoA reductase ">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_fabAA "Fab protein">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_fabRNA "FAB RNA mmol/g">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_fabDNA "FAB DNA mmol/g">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_pFAB "total fab g/g fab">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_fabt "FAB transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_fab "fab exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PROTEINSglycmet05 "Aminoacid compositionmu 0.05 (mmol/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PROTEINSglycmet16 "Aminoacid compositionmu 0.16 (mmol/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS8020 "Biomass composition 80:20 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS6040 "Biomass composition 60:40 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS4060 "Biomass composition 40:60 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS8020b "Biomass composition 80:20 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS6040b "Biomass composition 60:40 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS4060b "Biomass composition 40:60 (g/g)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_rolAA "ROL protein">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_rolRNA "ROL RNA mmol/g">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_rolDNA "ROL DNA mmol/g">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_pROL "total ROL g/g fab">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_ROLt "ROL transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_rol "rol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA200COAabcp "peroxisomal transport of eicosanoyl-CoA">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA220COAabcp "peroxisomal transport of docosanoyl-CoA">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_H2Otg "Water transport into golgi">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RMNt "L-rhamnose transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RMNDH "L-rhamnose dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RHAMLAC "L-rhamnonic acid lactonase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RHAMDH "L-rhamnonate dehydratase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_KDRALD "2-keto-3-deoxy-L-rhamnonate aldolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_rmn "L-rhamnose exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAKx "Dihydroxyacetone kinase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FBAx "fructose-bisphosphate aldolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FBPx "fructose-bisphosphatase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TKT2x "transketolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FBA3x "Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_SHBPH "Sedoheptulose bisphosphatase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_TKT1x "transketolase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RPIx "ribose-5-phosphate isomerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_RPEx "ribulose 5-phosphate 3-epimerase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_DHAPtx "Dihydroxyacetone phosphate transport from peroxisomes">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA140tpc "Tetradecanoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA141tpc "Tetradecenoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA160tpc "Hexadecanoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA161tpc "Hexadecenoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA180tpc "Octadecanoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA181tpc "Octadecenoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA182tpc "Octadecadienoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA183tpc "Octadecadienoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_FA260tpc "Hexacosanoate transport out of peroxisome">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LIPIDS_glyc "Lipid composition (mmol/g)- Glycerol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PROTEINS_glyc "Aminoacid composition (mmol/g) - Glycerol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_STEROLS_glyc "Sterol composition (mmol/mmol)- Glycerol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS_glyc "Biomass composition (g/g)- Glycerol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_LIPIDS_meoh "Lipid composition (mmol/g)- Methanol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_PROTEINS_meoh "Aminoacid composition (mmol/g) - Methanol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_STEROLS_meoh "Sterol composition (mmol/mmol)- Methanol">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_BIOMASS_meoh "Biomass composition (g/g)- Methanol">
# <Model iMT1026v3 at 0x1bb0e182ec8>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Ex_biomass = 0.05774990959595994</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glyc_e</td>
#       <td>Ex_glyc</td>
#       <td>1</td>
#       <td>3</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>Ex_nh4</td>
#       <td>0.3582</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>Ex_o2</td>
#       <td>1.45</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>Ex_pi</td>
#       <td>0.01453</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>Ex_so4</td>
#       <td>0.002533</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>biomass_e</td>
#       <td>Ex_biomass</td>
#       <td>-0.05775</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>Ex_co2</td>
#       <td>-0.9782</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>Ex_h</td>
#       <td>-0.3754</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>Ex_h2o</td>
#       <td>-2.715</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Change grwoth on glycerol to growth on 60% glucose and 40% methanol
# Add reaction describing this growth

biomass_gly = model.reactions.get_by_id('BIOMASS_glyc')
biomass_gly.bounds = (0,0)
biomass_gly

carbs = model.metabolites.get_by_id('CARBOHYDRATES_c')
DNA = model.metabolites.get_by_id('DNA_c')
lipids = model.metabolites.get_by_id('LIPIDS_c')
prot = model.metabolites.get_by_id('PROTEIN_c')
RNA = model.metabolites.get_by_id('RNA_c')
atp = model.metabolites.get_by_id('atp_c')
cof = model.metabolites.get_by_id('cof_c')
h2o = model.metabolites.get_by_id('h2o_c')
adp = model.metabolites.get_by_id('adp_c')
biomass = model.metabolites.get_by_id('biomass_c')
h = model.metabolites.get_by_id('h_c')
pi = model.metabolites.get_by_id('pi_c')

biomass_glc_meoh = Reaction ('biomass_glc_meoh_60/40')
biomass_glc_meoh.name = 'Biomass composition (g/g) - 60/40 Glucose/Methanol'
biomass_glc_meoh.add_metabolites({carbs: -0.33,
                                   DNA: -0.001,
                                   lipids: -0.042,
                                   prot: -0.49,
                                   RNA: -0.058,
                                   atp: -63.85,
                                   cof: -1,
                                   h2o: -63.85,
                                   adp: 63.85,
                                   pi: 63.85,
                                   biomass: 1,
                                   h: 63.85})
biomass_glc_meoh
# Out:
# <Reaction biomass_glc_meoh_60/40 at 0x1bb13e1cd88>

# %%
# Add new biomass reaction to the model

print (len(model.reactions))
model.add_reactions([biomass_glc_meoh])
print (len(model.reactions))
# Out:
# 2237
# 2238

# %%
#Tanquem l'entrada de Glicerol
glycerol_exchange = model.exchanges.get_by_id('Ex_glyc')
glycerol_exchange.bounds = (0,0)
glycerol_exchange
# Out:
# <Reaction Ex_glyc at 0x1bb13461f08>

# %%
# Add qmeoh constraints observed in chemostat cultivations
methanol_exchange = model.exchanges.get_by_id('Ex_meoh')
methanol_exchange.bounds = (-1.24, -1.18)
methanol_exchange
# Out:
# <Reaction Ex_meoh at 0x1bb1346bbc8>

# %%
# Add qgluc constraints observed in chemostat cultivations
glucose_exchange = model.reactions.get_by_id('Ex_glc_D')
glucose_exchange.bounds = (-0.72, -0.7)
glucose_exchange
# Out:
# <Reaction Ex_glc_D at 0x1bb1344f188>

# %%
# Change the reactions for the synthesis of lipids, proteins and sterols from glycerol to those from glucose

model.reactions.get_by_id('LIPIDS_glyc').bounds = (0,0)
model.reactions.get_by_id('PROTEINS_glyc').bounds = (0,0)
model.reactions.get_by_id('STEROLS_glyc').bounds = (0,0)

# note: these reactions from glucose do not have the glucose specification
model.reactions.get_by_id('LIPIDS').bounds = (0,1000)
model.reactions.get_by_id('PROTEINS').bounds = (0,1000)
model.reactions.get_by_id('STEROLS').bounds = (0,1000)

# %%
# ATP maintenance requirement (NGAME = Non-Growth Associated Maintenance Energy) based on previous studies on 
# the growth of X33-ROL on Gluc/MeOH from the group (Eric's Master Thesis)

model.reactions.get_by_id('ATPM').bounds = (1.96, 1000)

# %%
rolAA = model.reactions.get_by_id('rolAA')
rolAA.bounds = (0,0)
rolRNA = model.reactions.get_by_id('rolRNA')
rolRNA.bounds = (0,0)
rolDNA = model.reactions.get_by_id('rolDNA')
rolDNA.bounds = (0,0)
pROL = model.reactions.get_by_id('pROL')
pROL.bounds = (0,0)
Rol_transport =  model.reactions.get_by_id('ROLt')
Rol_transport.bounds = (0,0)
ROL_exchange = model.exchanges.get_by_id('Ex_rol')
#ROL_exchange.bounds = (0.0003773,1000)
ROL_exchange.bounds = (0,0) # Inferit de Bradford

pFAB = model.reactions.get_by_id('pFAB')
pFAB.bounds = (0,0)
fabAA = model.reactions.get_by_id('fabAA')
fabAA.bounds = (0,0)
fabt = model.reactions.get_by_id('fabt')
fabt.bounds = (0,0)
fabRNA = model.reactions.get_by_id('fabRNA')
fabRNA.bounds = (0,0)
fabDNA = model.reactions.get_by_id('fabDNA')
FAB_exchange = model.exchanges.get_by_id('Ex_fab')
FAB_exchange.bounds = (0,0)


# Extra reactions that must be closed for simulations to run smoothly:

APAT2r = model.reactions.get_by_id('APAT2r')
APAT2r.bounds = (0,0) # reaction not present in Pichia, it is yet to be removed from the model

MMSAD3 = model.reactions.get_by_id('MMSAD3')
MMSAD3.bounds = (0,0) # The reduction reaction of MSA into Acetil-CoA it is due to an unspecific effect. Reaction
# under evaluation of being kept or not.

# %%
# REACTION RATIOS PER GLUCOSA METANOL

ReactionRatio1 = model.problem.Constraint(model.reactions.CSm.flux_expression - model.reactions.ACONTm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio1)

ReactionRatio2 = model.problem.Constraint(model.reactions.AKGDam.flux_expression - model.reactions.FUMm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio2)

ReactionRatio8 = model.problem.Constraint(68*model.reactions.AKGDam.flux_expression - 46*model.reactions.CSm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio8)

ReactionRatio9 = model.problem.Constraint(model.reactions.G6PDH2.flux_expression - model.reactions.GND.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio9)

ReactionRatio10 = model.problem.Constraint(0.8*model.reactions.MDHm.flux_expression - model.reactions.FUMm.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio10)

ReactionRatio12 = model.problem.Constraint(35*model.reactions.PYK.flux_expression - 143*model.reactions.PC.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio12)

ReactionRatio13 = model.problem.Constraint(68*model.reactions.PYK.flux_expression - 143*model.reactions.PYRt2m.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio13)


ReactionRatio14 = model.problem.Constraint(40*model.reactions.GAPD.flux_expression - 145*model.reactions.FBA.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio14)


ReactionRatio16 = model.problem.Constraint(model.reactions.GAPD.flux_expression - model.reactions.PYK.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio16)

ReactionRatio20 = model.problem.Constraint(0.18*model.reactions.FALDtx.flux_expression - 0.82*model.reactions.DAS.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio20)

ReactionRatio21 = model.problem.Constraint(model.reactions.G6PDH2.flux_expression + 0.4*model.reactions.Ex_glc_D.flux_expression,
                                         lb=0,
                                         ub=0)
model.add_cons_vars(ReactionRatio21)

# %%
pfba_WT = cobra.flux_analysis.pfba(model)

# %%
pfba_WT.fluxes['Ex_biomass']
# Out:
# 0.08372438853447359

# %%
nadph_producing_reactions = []

nadph_c = model.metabolites.get_by_id("nadph_c")

for reaction in model.reactions:
    coefficient = reaction.metabolites.get(nadph_c, 0)

    if coefficient > 0:
        nadph_producing_reactions.append({
            "ID": reaction.id,
            "Name": reaction.name,
            "Reaction": reaction.reaction,
            "NADPH stoichiometry": coefficient
        })

for r in nadph_producing_reactions:
    print(r["ID"], "|", r["Name"], "|", r["NADPH stoichiometry"])
# Out:
# CER4DS16 | Ceramide delta-4 desaturase (C16:0) | 1.0
# CER4DS18 | Ceramide delta-4 desaturase (C18:0) | 1.0
# CER4DS2d16 | Ceramide delta-4 desaturase (C16OH) | 1.0
# CER4DS2d18 | Ceramide delta-4 desaturase (C18OH) | 1.0
# CER8DS16 | Ceramide delta-8 desaturase (C16:1) | 1.0
# CER8DS18 | Ceramide delta-8 desaturase (C18:1) | 1.0
# CER8DS2d16 | Ceramide delta-8 desaturase (C16OH:1) | 1.0
# CER8DS2d18 | Ceramide delta-8 desaturase (C18OH:1) | 1.0
# ARAB1D2 | D-arabinose 1-dehydrogenase (NADP) | 1.0
# ALDD20y | aldehyde dehydrogenase (indole-3-acetaldehyde, NADP) | 1.0
# ALDD2y | aldehyde dehydrogenase (acetaldehyde, NADP) | 1.0
# ATHRDHr | L-allo-threonine dehydrogenase | 1.0
# LSERDHr | L-serine dehydrogenase | 1.0
# GLYCDy | Glycerol dehydrogenase (NADP-dependent) | 1.0
# APRAUR | 5-amino-6-(5-phosphoribosylamino)uracil reductase | 1.0
# FRDO | frdo | 1.0
# FTHFDH | formyltetrahydrofolate dehydrogenase | 1.0
# BDGLC1R | beta-D-Glucose:NADP+ 1-oxoreductase | 1.0
# ICDOXSUC | Isocitrate:NADP+ oxidoreductase | 1.0
# G6PDH2 | glucose 6-phosphate dehydrogenase | 1.0
# GND | phosphogluconate dehydrogenase | 1.0
# HMGCOAR | Hydroxymethylglutaryl CoA reductase | 2.0
# ICDHy | isocitrate dehydrogenase (NADP) | 1.0
# MTHFD | methylenetetrahydrofolate dehydrogenase (NADP) | 1.0
# PPND2 | prephenate dehydrogenase (NADP) | 1.0
# SSALy | succinate-semialdehyde dehydrogenase (NADP) | 1.0
# SULR | sulfite reductase (NADPH2) | 3.0

# %%
increase = 0.20  # 20% increase

nadph_c = model.metabolites.get_by_id("nadph_c")

with model:

    # --------------------------------------------------
    # 1. Identify NADPH-producing reactions
    #    based on the pFBA_WT flux direction
    # --------------------------------------------------

    nadph_producing_reactions = []

    for reaction in model.reactions:

        nadph_stoich = reaction.metabolites.get(nadph_c, 0)
        reference_flux = pfba_WT.fluxes[reaction.id]

        # Net NADPH production in the WT pFBA solution
        if reference_flux * nadph_stoich > 0:

            target_flux = reference_flux * (1 + increase)

            nadph_producing_reactions.append({
                "ID": reaction.id,
                "Name": reaction.name,
                "Reference flux": reference_flux,
                "NADPH stoichiometry": nadph_stoich,
                "Reference NADPH production": (
                    reference_flux * nadph_stoich
                ),
                "Target flux": target_flux
            })

            # Require at least the increased flux
            reaction.lower_bound = target_flux


    # --------------------------------------------------
    # 2. Perform MOMA using pfba_WT as reference
    # --------------------------------------------------

    moma_result = cobra.flux_analysis.moma(
        model,
        solution=pfba_WT,
        linear=False
    )

print("MOMA status:", moma_result.status)
# Out:
# C:\Users\Eric\miniconda3\envs\s2m2\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# MOMA status: infeasible

# %%
## Afegir aqui linea de codi per comprovar que la simulació MOMA té un turnover rate més alt que el pfba de ref

# %%
# 2. Calculate flux changes

reaction_changes = []

for reaction in model.reactions:

    reaction_id = reaction.id

    reference_flux = pfba_WT.fluxes[reaction_id]
    moma_flux = moma_result.fluxes[reaction_id]

    absolute_change = abs(moma_flux - reference_flux)

    # Proportional change
    if abs(reference_flux) > 1e-12:
        proportional_change = absolute_change / abs(reference_flux)
    else:
        proportional_change = np.nan

    reaction_changes.append({
        "ID": reaction_id,
        "Name": reaction.name,
        "pFBA flux": reference_flux,
        "MOMA flux": moma_flux,
        "Absolute change": absolute_change,
        "Proportional change": proportional_change
    })

# %%
flux_threshold = 1e-6

proportional_changes = sorted(
    [
        r for r in reaction_changes
        if abs(r["pFBA flux"]) > flux_threshold
    ],
    key=lambda x: x["Proportional change"],
    reverse=True
)

print("Reactions ordered by proportional flux change:\n")

for r in proportional_changes:
    print(
        r["ID"],
        "|", r["Name"],
        "| pFBA =", r["pFBA flux"],
        "| MOMA =", r["MOMA flux"],
        "| proportional change =", r["Proportional change"]
    )
# Out:
# Reactions ordered by proportional flux change:
#
# GLYC3Ptmc | glycerol-3-phosphate shuttle | pFBA = 9.952817062448541e-06 | MOMA = 3.1025625507654886 | proportional change = 311726.07498777355
# G3PD1ir | glycerol-3-phosphate dehydrogenase (NAD) | pFBA = 0.0032981959043510934 | MOMA = 3.1142647940963757 | proportional change = 943.2328122437877
# TYRTAi | tyrosine transaminase, irreversible | pFBA = 0.007753715622177599 | MOMA = 0.08080989784571048 | proportional change = 9.422086878524874
# TKT2 | transketolase | pFBA = -0.0035421563557020627 | MOMA = 0.014811873692134412 | proportional change = 5.18159793208752
# CYSTH2SS | L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming) | pFBA = 0.0005422373101884111 | MOMA = 0.0033006042170316057 | proportional change = 5.0870105302874595
# GLYtm | glycine passive transport to mitochondria | pFBA = -0.014953911860982272 | MOMA = -0.0907554956423575 | proportional change = 5.069013679233769
# MTHFCm | methenyltetrahydrifikate cyclohydrolase, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | proportional change = 5.068786223953768
# 10FTHFtm | 10-Formyltetrahydrofolate mitochondrial transport via diffusion | pFBA = -0.014954581656090538 | MOMA = -0.09075615913947398 | proportional change = 5.068786223953768
# THFtm | 5,6,7,8-Tetrahydrofolate transport, diffusion, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | proportional change = 5.068786223953768
# SERtm | L-Serine mitochondrial permease | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | proportional change = 5.068786223953768
# GHMT2rm | glycine hydroxymethyltransferase, reversible, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | proportional change = 5.068786223953768
# MTHFDm | methylenetetrahydrofolate dehydrogenase (NADP), mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | proportional change = 5.068786223953768
# MTHFD | methylenetetrahydrofolate dehydrogenase (NADP) | pFBA = -0.05021557927219475 | MOMA = -0.2186088444384906 | proportional change = 3.3534068033650697
# 3MOBtm | 3-methyl-2-oxobutanoate transport, diffusion, mitochondrial | pFBA = -0.020808395350066025 | MOMA = -0.0829312594018384 | proportional change = 2.9854711527083353
# RNDR1 | ribonucleoside-diphosphate reductase (ADP) | pFBA = 2.3953547559726286e-05 | MOMA = 7.932937398842667e-05 | proportional change = 2.3118006337318144
# MALOAAtp | malate/oxaloacetate shuttle | pFBA = 0.08741275608997044 | MOMA = 0.2464129769535105 | proportional change = 1.818959016689595
# VALTA | valine transaminase | pFBA = -0.02079964984361927 | MOMA = -0.05788884992362742 | proportional change = 1.783164637811729
# GHMT2r | glycine hydroxymethyltransferase, reversible | pFBA = -0.044238840209953875 | MOMA = -0.12253021692656366 | proportional change = 1.7697429757436087
# TALA | transaldolase | pFBA = 0.015462064615577385 | MOMA = 0.0403314555311169 | proportional change = 1.608413335078463
# MTHFC | methenyltetrahydrofolate cyclohydrolase | pFBA = -0.05021557927219475 | MOMA = -0.12845208277517947 | proportional change = 1.5580125657597592
# NADPHter | NADPH transport into ER | pFBA = 0.0019321173810279476 | MOMA = 0.003980627351352276 | proportional change = 1.0602409514242122
# NADPter | NADP transport into ER | pFBA = -0.0019321173810279476 | MOMA = -0.003980627351352276 | proportional change = 1.0602409514242122
# NADHter | NADH transport into ER | pFBA = 0.0020862945481351335 | MOMA = 0.0 | proportional change = 1.0
# NADter | NAD transport into ER | pFBA = -0.0020862945481351335 | MOMA = 0.0 | proportional change = 1.0
# D_LACtm | D-lactate transport, mitochondrial | pFBA = 0.010561904044374737 | MOMA = 0.0 | proportional change = 1.0
# FBA3 | Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase | pFBA = 0.005118617302050134 | MOMA = 0.0 | proportional change = 1.0
# ICDHxm | Isocitrate dehydrogenase (NAD+) | pFBA = 0.2798853568467663 | MOMA = 0.0 | proportional change = 1.0
# ICDHym | Isocitrate dehydrogenase (NADP+) | pFBA = 0.07666304550189824 | MOMA = 0.0 | proportional change = 1.0
# IPPSm | 2-isopropylmalate synthase, mitochondrial | pFBA = 0.025271369435245508 | MOMA = 0.0 | proportional change = 1.0
# MEVK2 | mevalonate kinase (ctp) | pFBA = 0.0030218593720087172 | MOMA = 0.0 | proportional change = 1.0
# NADH2_u6cm | NADH dehydrogenase, cytosolic/mitochondrial | pFBA = 3.029122511463296 | MOMA = 0.0 | proportional change = 1.0
# PFK_3 | phosphofructokinase (s7p) | pFBA = 0.005118617302050134 | MOMA = 0.0 | proportional change = 1.0
# RNTR1 | ribonucleoside-triphosphate reductase (ATP) | pFBA = 5.612883007349769e-05 | MOMA = 0.0 | proportional change = 1.0
# SUCD2_u6m | succinate dehydrogenase (ubiquinone-6), mitochondrial | pFBA = 0.28679931446689166 | MOMA = 0.0 | proportional change = 1.0
# D_LACt2m | D-lactate/pyruvate antiport, mitochondrial | pFBA = -0.010561904044374737 | MOMA = 0.0 | proportional change = 1.0
# AHSERL2 | O-acetylhomoserine (thiol)-lyase | pFBA = 0.0027896966259686596 | MOMA = 0.0 | proportional change = 1.0
# DHAD1 | dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylbutanoate) | pFBA = 0.04607976478531153 | MOMA = 0.0 | proportional change = 1.0
# PUTA3 | puta3 | pFBA = -0.013579258576406272 | MOMA = 0.0 | proportional change = 1.0
# 1PYR5Ctm | 1-Pyrroline-5-carboxylate transport into mitochondria | pFBA = 0.013579258576406272 | MOMA = 0.0 | proportional change = 1.0
# G5SADsm | L-glutamate 5-semialdehyde dehydratase (spontaneous) | pFBA = 0.013579258576406272 | MOMA = 0.0 | proportional change = 1.0
# CERS224 | Ceramide-2 synthase (24C) | pFBA = 1.3726041693865707e-05 | MOMA = 0.0 | proportional change = 1.0
# CERS226 | Ceramide-2 synthase (26C) | pFBA = 9.634784617052615e-06 | MOMA = 0.0 | proportional change = 1.0
# 3C3HMPtm | 2-Isopropylmalate transport, diffusion, mitochondrial | pFBA = -0.025271369435245508 | MOMA = 0.0 | proportional change = 1.0
# 3MOPtm | 3-Methyl-2-oxopentanoate transport, diffusion, mitochondrial | pFBA = -0.015876655797792228 | MOMA = 0.0 | proportional change = 1.0
# ALATA_L | L-alanine transaminase | pFBA = -0.1007105019233753 | MOMA = 0.0 | proportional change = 1.0
# ASPTA | aspartate transaminase | pFBA = -0.14092571758987232 | MOMA = 0.0 | proportional change = 1.0
# ICL | Isocitrate lyase | pFBA = 0.06247508071856199 | MOMA = 0.0 | proportional change = 1.0
# ILETA | isoleucine transaminase | pFBA = -0.015876655797792228 | MOMA = 0.0 | proportional change = 1.0
# NDPK1 | nucleoside-diphosphate kinase (ATP:GDP) | pFBA = 0.011005751374356883 | MOMA = 0.0 | proportional change = 1.0
# OAAt2m | oxaloacetate transport, mitochondrial | pFBA = 0.01755951600733513 | MOMA = 0.0 | proportional change = 1.0
# PHETA1 | phenylalanine transaminase | pFBA = -0.011281861355020316 | MOMA = 0.0 | proportional change = 1.0
# PSPHS | Phytosphingosine synthesis | pFBA = 2.3360826310918323e-05 | MOMA = 0.0 | proportional change = 1.0
# SQLErx | Squalene epoxidase, endoplasmic reticular (NAD) | pFBA = 0.0020862945481351335 | MOMA = 0.0 | proportional change = 1.0
# FAE1_18 | palmitoyl-CoA:malonyl-CoA C-acyltransferase | pFBA =
# CITMALS | D-citramalate synthase | pFBA = 0.015876655797792228 | MOMA = 0.01849083526473573 | proportional change = 0.16465554838740185
# RPE | ribulose 5-phosphate 3-epimerase | pFBA = 0.24023852556192538 | MOMA = 0.27834341216039105 | proportional change = 0.15861272254038838
# MCOATA | Malonyl-CoA-ACP transacylase | pFBA = 0.043672245813761015 | MOMA = 0.05041319169598127 | proportional change = 0.15435308527449712
# PDHa2 | pyruvate dehydrogenase (lipoamide) | pFBA = 0.37643547037377373 | MOMA = 0.31882573663733244 | proportional change = 0.15304013109933268
# PDHbrm | pyruvate dehydrogenase (dihydrolipoamide) reversible | pFBA = 0.37643547037377373 | MOMA = 0.31882573663733244 | proportional change = 0.15304013109933268
# ADK1 | adenylate kinase | pFBA = 0.29408732978798025 | MOMA = 0.3382550237158348 | proportional change = 0.15018564029840015
# PDHa1 | pyruvate dehydrogenase (lipoamide) | pFBA = 0.39231212617156597 | MOMA = 0.3345531064119538 | proportional change = 0.1472272099342476
# MDH | malate dehydrogenase | pFBA = 0.050219529330550294 | MOMA = 0.057382275274928674 | proportional change = 0.14262869524786706
# ACACT1m | acetyl-CoA C-acetyltransferase, mitochondrial | pFBA = 0.012518269635142 | MOMA = 0.010776994742873726 | proportional change = 0.1390986887980163
# HEX1 | hexokinase (D-glucose:ATP) | pFBA = 0.4228571493465189 | MOMA = 0.47919060378205136 | proportional change = 0.13322100506658066
# ASADi | aspartate-semialdehyde dehydrogenase, irreversible | pFBA = 0.023917629797031603 | MOMA = 0.020929270104917363 | proportional change = 0.12494380578150445
# ASPKi | aspartate kinase, irreversible | pFBA = 0.023917629797031603 | MOMA = 0.020929270104917363 | proportional change = 0.12494380578150445
# HSDxi | homoserine dehydrogenase (NADH), irreversible | pFBA = 0.023917629797031603 | MOMA = 0.020929270104917363 | proportional change = 0.12494380578150445
# CITtam | citrate transport, mitochondrial | pFBA = 0.04906051364473802 | MOMA = 0.05482290500497823 | proportional change = 0.11745477028568077
# GCC2cm | glycine-cleavage complex (lipoamide), mitochondrial | pFBA = 0.6007603739172117 | MOMA = 0.5314230565737523 | proportional change = 0.1154159301342576
# ACtp | acetate transport, peroxisomal | pFBA = 0.08741275608997044 | MOMA = 0.09479769049871667 | proportional change = 0.08448348661086959
# ACSp | acetyl-CoA synthetase | pFBA = 0.08741275608997044 | MOMA = 0.09479769049871667 | proportional change = 0.08448348661086959
# PPItx | Diphosphate transporter, peroxisome | pFBA = 0.08741275608997044 | MOMA = 0.09479769049871667 | proportional change = 0.08448348661086959
# ATP2tp_H | AMP/ATP transporter, peroxisomal | pFBA = 0.08741275608997044 | MOMA = 0.09479769049871667 | proportional change = 0.08448348661086959
# CSp | citrate synthase | pFBA = 0.08741275608997044 | MOMA = 0.0943769024274927 | proportional change = 0.0796696803651214
# CO2tm | CO2 transport (diffusion), mitochondrial | pFBA = -1.0682368007884568 | MOMA = -0.9848856622547365 | proportional change = 0.07802683681389702
# CHORM | chorismate mutase | pFBA = 0.019035576977197915 | MOMA = 0.020480238302222627 | proportional change = 0.07589269958852435
# 3DSPHR | 3-Dehydrosphinganine reductase | pFBA = 3.200266124400559e-05 | MOMA = 3.339136596776074e-05 | proportional change = 0.04339341385289533
# SERPT | serine C-palmitoyltransferase | pFBA = 3.200266124400559e-05 | MOMA = 3.339136596776074e-05 | proportional change = 0.04339341385289533
# SUCFUMtm | succinate-fumarate transport, mitochondrial | pFBA = 0.062474410923453724 | MOMA = 0.06507299870152007 | proportional change = 0.04159443425965626
# FTHFLi | formate-tetrahydrofolate ligase | pFBA = 0.05758042192097007 | MOMA = 0.05980548144624662 | proportional change = 0.03864264017256544
# FUM | fumarase | pFBA = 0.10630075521652267 | MOMA = 0.11011081718779892 | proportional change = 0.035842285066701327
# AGTi | Alanine glyoxylate aminotransferase (irreversible) | pFBA = 0.06247524816745191 | MOMA = 0.06465295706455215 | proportional change = 0.03485714680577732
# AKGMALtm | alpha-ketoglutarate/malate transporter | pFBA = 0.10514240932570576 | MOMA = 0.10797289848619968 | proportional change = 0.026920527869261055
# PC | pyruvate carboxylase | pFBA = 0.2439241369032868 | MOMA = 0.24006986535655772 | proportional change = 0.01580110765445589
# ENO | enolase | pFBA = 0.996604330776286 | MOMA = 0.9808568784567929 | proportional change = 0.015801107654455866
# GAPD | glyceraldehyde-3-phosphate dehydrogenase | pFBA = 0.996604330776286 | MOMA = 0.9808568784567929 | proportional change = 0.015801107654455866
# PGK | phosphoglycerate kinase | pFBA = -0.996604330776286 | MOMA = -0.9808568784567929 | proportional change = 0.015801107654455866
# PGM | phosphoglycerate mutase | pFBA = -0.996604330776286 | MOMA = -0.9808568784567929 | proportional change = 0.015801107654455866
# PYK | pyruvate kinase | pFBA = 0.996604330776286 | MOMA = 0.9808568784567929 | proportional change = 0.015801107654455866
# FBA | fructose-bisphosphate aldolase | pFBA = 0.27492533262794094 | MOMA = 0.2705812078501498 | proportional change = 0.015801107654455818
# PYRt2m | pyruvate mitochondrial transport via proton symport | pFBA = 0.4739097516978143 | MOMA = 0.4664214526927407 | proportional change = 0.015801107654455807
# HCO3E | HCO3 equilibration reaction | pFBA = 0.3450464881685879 | MOMA = 0.34026367097714916 | proportional change = 0.013861370439747497
# CYOR_u6m | ubiquinol-6 cytochrome c reductase | pFBA = 4.4941018959432615 | MOMA = 4.5513890691385015 | proportional change = 0.01274719054477871
# H2Otm | H2O transport, mitochondrial | pFBA = -11.822271600266708 | MOMA = -11.971465355668736 | proportional change = 0.012619719834440424
# CO2t | CO2 transporter via diffusion | pFBA = -2.3730677521508166 | MOMA = -2.4029701537829187 | proportional change = 0.012600736580318975
# Ex_co2 | CO2 exchange | pFBA = 2.3730677521508166 | MOMA = 2.4029701537829187 | proportional change = 0.012600736580318975
# CYOOm | cytochrome c oxidase, mitochondrial | pFBA = 2.251116019582741 | MOMA = 2.2788942765464317 | proportional change = 0.012339771349874597
# O2tm | O2 transport (diffusion) | pFBA = 2.251116354480295 | MOMA = 2.2788946082949897 | proportional change = 0.012339768115232637
# O2t | o2 transport (diffusion) | pFBA = 2.9071704610978664 | MOMA = 2.9378583354763252 | proportional change = 0.010555925353916083
# Ex_o2 | Oxygen exchange | pFBA = -2.9071704610978664 | MOMA = -2.9378583354763252 | proportional change = 0.010555925353916083
# ATPS3m | ATP synthase, mitochondrial | pFBA = 7.915787564207878 | MOMA = 7.993910543071864 | proportional change = 0.009869261678677256
# COAtim | CoA transporter (mitochondrial), irreversible | pFBA = 0.012518269635142007 | MOMA = 0.012400562057763409 | proportional change = 0.009402863239833279
# CYTK1 | cytidylate kinase (CMP) | pFBA = -0.0030218593720087172 | MOMA = -0.002993445241604017 | proportional change = 0.009402863239731904
# UMPK | UMP kinase | pFBA = 0.003911025734049722 | MOMA = 0.0038742508939453996 | proportional change = 0.00940286323972708
# DHORD4i | dihydoorotic acid (ubiquinone-6), irreversible | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | proportional change = 0.009402863239726724
# ASPCT | aspartate carbamoyltransferase | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | proportional change = 0.009402863239726724
# DHORTS | dihydroorotase | pFBA = -0.007610337606812317 | MOMA = -0.007538778643087312 | proportional change = 0.009402863239726724
# OMPDC | orotidine-5'-phosphate decarboxylase | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | proportional change = 0.009402863239726724
# ORPT | orotate phosphoribosyltransferase | pFBA = -0.007610337606812317 | MOMA = -0.007538778643087312 | proportional change = 0.009402863239726724
# ZYMSTAT_PP | Acyl-CoA:zymosterol acyltransferase, yeast-specific | pFBA = 1.5511861938996446e-05 | MOMA = 1.5366006022590543e-05 | proportional change = 0.00940286323972653
# GLCCERS18d8 | Glucoceramide synthase (C18OH:2) | pFBA = 1.5890235852252672e-06 | MOMA = 1.574082213768694e-06 | proportional change = 0.009402863239726514
# CERavg | Average ceramide | pFBA = 1.625572633932091e-06 | MOMA = 1.6102875967689856e-06 | proportional change = 0.009402863239726491
# ERGSTter | Ergosterol transport, ER | pFBA = 0.0019321173810279476 | MOMA = 0.0019139499455310433 | proportional change = 0.009402863239726488
# ERGTETROLter | Ergosta-5,6,22,24,(28)-tetraen-3beta-ol endoplamic reticular transport | pFBA = 0.0019321173810279476 | MOMA = 0.0019139499455310433 | proportional change = 0.009402863239726488
# C22STDSx | C-22 sterol desaturase (NAD) | pFBA = 0.0019321173810279476 | MOMA = 0.0019139499455310433 | proportional change = 0.009402863239726488
# C24STRer | C-s24 sterol reductase, endoplamic reticular | pFBA = 0.0019321173810279476 | MOMA = 0.0019139499455310433 | proportional change = 0.009402863239726488
# C5STDS | C-5 sterol desaturase | pFBA = 0.0019321173810279476 | MOMA = 0.0019139499455310433 | proportional change = 0.009402863239726488
# MAN1PT2 | mannose-1-phosphate guanylyltransferase (GDP) | pFBA = 0.028473471401058343 | MOMA = 0.02820573924351393 | proportional change = 0.00940286323972648
# MAN6PI | mannose-6-phosphate isomerase | pFBA = -0.028473471401058343 | MOMA = -0.02820573924351393 | proportional change = 0.00940286323972648
# PMANM | phosphomannomutase | pFBA = -0.028473471401058343 | MOMA = -0.02820573924351393 | proportional change = 0.00940286323972648
# CLPNtm | Cardiolipin transport to cytosol for phospholipid composition | pFBA = 9.952817062448541e-06 | MOMA = 9.859232084760322e-06 | proportional change = 0.009402863239726457
# PAtm_PP | phosphatidate reversible transport, mitochondrial, yeast-specific | pFBA = 1.9905634124897083e-05 | MOMA = 1.9718464169520643e-05 | proportional change = 0.009402863239726457
# DASYNm_PP | CDP-Diacylglycerol synthetase, yeast-specific, mitochondrial | pFBA = 1.9905634124897083e-05 | MOMA = 1.9718464169520643e-05 | proportional change = 0.009402863239726457
# CTPtm | CTP/CMP antiport | pFBA = 1.9905634124897083e-05 | MOMA = 1.9718464169520643e-05 | proportional change = 0.009402863239726457
# CDPDGPm_PP | CDP-diacylglycerol--serine O-phosphatidyltransferae, yeast-specific, mitochondrial | pFBA = 9.952817062448541e-06 | MOMA = 9.859232084760322e-06 | proportional change = 0.009402863239726457
# CLPNSm_PP | cardiolipin synthase, yeast-specific, mitochondrial | pFBA = 9.952817062448541e-06 | MOMA = 9.859232084760322e-06 | proportional change = 0.009402863239726457
# PGPPAm_PP | phosphatidylglycerol phosphate phosphatase A, yeast-specific, mitochondrial | pFBA = 9.952817062448541e-06 | MOMA = 9.859232084760322e-06 | proportional change = 0.009402863239726457
# SPHLIPIDS | Sphingolipid composition | pFBA = 3.199946129787581e-05 | MOMA = 3.1698574739546964e-05 | proportional change = 0.009402863239726455
# ERGSTAT_PP | Acyl-CoA:ergosterol acyltransferase, yeast-specific | pFBA = 0.0003800406175054129 | MOMA = 0.0003764671475534683 | proportional change = 0.009402863239726453
# STERYLEST | Steryl ester composition (mmol/mmol) | pFBA = 0.0004103667179628689 | MOMA = 0.00040650809583572865 | proportional change = 0.009402863239726451
# LIPIDS | Lipid composition (mmol/g) | pFBA = 0.003516424318447891 | MOMA = 0.0034833598614886774 | proportional change = 0.00940286323972642
# DASYN_PP | CDP-Diacylglycerol synthetase, yeast-specific | pFBA = 0.0007245551869282218 | MOMA = 0.0007177422935959013 | proportional change = 0.009402863239726408
# PETOHM_PP | phosphatidylethanolamine N-methyltransferase, yeast-specific | pFBA = 0.00036536935679974144 | MOMA = 0.00036193383870576667 | proportional change = 0.009402863239726403
# PMETM_PP | Phosphatidyl-N-methylethanolamine N-methyltransferase, yeast-specific | pFBA = 0.00036536935679974144 | MOMA = 0.00036193383870576667 | proportional change = 0.009402863239726403
# MFAPS_PP | methylene-fatty-acyl-phospholipid synthase, yeast-specific | pFBA = 0.00036536935679974144 | MOMA = 0.00036193383870576667 | proportional change = 0.009402863239726403
# PHOSPHOLIPIDS | Phospholipid composition (mmol/mmol) | pFBA = 0.0007212186277136624 | MOMA = 0.0007144371075913277 | proportional change = 0.0094028632397264
# C3STDH2 | C-3 sterol dehydrogenase (zymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C3STKR2 | C-3 sterol keto reductase (zymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C4STMO2 | C-4 sterol methyl oxidase (4-methylzymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# LNS14DMx | cytochrome P450 lanosterol 14-alpha-demethylase (NAD) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C14STR | C-14 sterol reductase | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C3STDH1 | C-3 sterol dehydrogenase (4-methylzymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C3STKR1 | C-3 sterol keto reductase (4-methylzymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# C4STMO1 | C-4 sterol methyl oxidase (4,4-dimethylzymosterol) | pFBA = 0.0020760717048492715 | MOMA = 0.002056550686532708 | proportional change = 0.009402863239726394
# EPISTAT_PP | Acyl-CoA:episterol acyltransferase, yeast-specific | pFBA = 6.401720800220755e-06 | MOMA = 6.341526295037367e-06 | proportional change = 0.009402863239726375
# FECOSTAT_PP | Acyl-CoA:fecosterol acyltransferase, yeast-specific | pFBA = 6.401720800220755e-06 | MOMA = 6.341526295037367e-06 | proportional change = 0.009402863239726375
# ALACPYRL | (S)-2-Aceto-2-hydroxybutanoate pyruvate-lyase (carboxylating) | pFBA = 0.015876655797792228 | MOMA = 0.01572736977462138 | proportional change = 0.009402863239726373
# 3H3M2OPR | (R)-2,3-Dihydroxy-3-methylpentanoate:NADP+ oxidoreductase | pFBA = 0.015876655797792228 | MOMA = 0.01572736977462138 | proportional change = 0.009402863239726373
# 3H3M2OPS | (R)-2,3-Dihydroxy-3-methylpentanoate:NADP+ oxidoreductase | pFBA = 0.015876655797792228 | MOMA = 0.01572736977462138 | proportional change = 0.009402863239726373
# DHAD2m | dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylpentanoate), mitochondrial | pFBA = 0.015876655797792228 | MOMA = 0.01572736977462138 | proportional change = 0.009402863239726373
# 2OBUTtm | 2obut transporter (mitochondrial) | pFBA = 0.015876655797792228 | MOMA = 0.01572736977462138 | proportional change = 0.009402863239726373
# 13GS | 1,3-beta-glucan synthase | pFBA = 0.08468303278319331 | MOMA = 0.08388676980720768 | proportional change = 0.009402863239726372
# C8STI | C-8 sterol isomerase | pFBA = 0.0019646635759788555 | MOMA = 0.0019461901130618546 | proportional change = 0.009402863239726365
# GLCCERavg | Average glucoceramide | pFBA = 7.04948132392204e-06 | MOMA = 6.983196015122196e-06 | proportional change = 0.009402863239726361
# LANOSTAT_PP | Acyl-CoA:lanosterol acyltransferase, yeast-specific | pFBA = 2.0107969180180574e-06 | MOMA = 1.9918896695950703e-06 | proportional change = 0.00940286323972636
# CERS326 | Ceramide-3 synthase (26C) | pFBA = 9.497564399117219e-06 | MOMA = 9.408260099961826e-06 | proportional change = 0.009402863239726356
# PSERS_PP | phosphatidylserine synthase, yeast-specific | pFBA = 0.0006489525212167535 | MOMA = 0.0006428505094106768 | proportional change = 0.009402863239726356
# SAM24MT | S-adenosyl-methionine delta-24-sterol-c-methyltransferase | pFBA = 0.0019972097709297634 | MOMA = 0.0019784302805926656 | proportional change = 0.009402863239726354
# growth | Growth | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | proportional change = 0.009402863239726349
# COF | Cofactor composition (mmol/g DCW) | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | proportional change = 0.009402863239726349
# Ex_biomass | Biomass exchange | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | proportional change = 0.009402863239726349
# biomass_glc_meoh_60/40 | Biomass composition (g/g) - 60/40 Glucose/Methanol | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | proportional change = 0.009402863239726349
# P5CRm | pyrroline-5-carboxylate reductase (m) | pFBA = 0.013579258576406272 | MOMA = 0.013451574665115443 | proportional change = 0.009402863239726344
# 3C4MOPtm | 3-Carboxy-4-methyl-2-oxopentanoate transport, diffusion, mitochondrial | pFBA = 0.025271369435245508 | MOMA = 0.025033746204565294 | proportional change = 0.009402863239726342
# OMCDCm | 2-oxo-4-methyl-3-carboxypentanoate decarboxylation | pFBA = 0.025271369435245508 | MOMA = 0.025033746204565294 | proportional change = 0.009402863239726342
# 4MOPtm | 4-Methyl-2-oxopentanoate transport into mitochondria | pFBA = -0.025271369435245508 | MOMA = -0.025033746204565294 | proportional change = 0.009402863239726342
# IPMD | 3-isopropylmalate dehydrogenase | pFBA = 0.025271369435245508 | MOMA = 0.025033746204565294 | proportional change = 0.009402863239726342
# IPPMIa | 3-isopropylmalate dehydratase | pFBA = -0.025271369435245508 | MOMA = -0.025033746204565294 | proportional change = 0.009402863239726342
# IPPMIb | 2-isopropylmalate hydratase | pFBA = -0.025271369435245508 | MOMA = -0.025033746204565294 | proportional change = 0.009402863239726342
# LEUTA | leucine transaminase | pFBA = -0.025271369435245508 | MOMA = -0.025033746204565294 | proportional change = 0.009402863239726342
# STEROLS | Sterol composition (mmol/mmol) | pFBA = 0.001675927830172265 | MOMA = 0.0016601693099855038 | proportional change = 0.00940286323972634
# ACGAM6PS | N-acetylglucosamine-6-phosphate synthase | pFBA = 0.005663954884357138 | MOMA = 0.005610697491183548 | proportional change = 0.009402863239726337
# ACGAMPM | phosphoacetylglucosamine mutase | pFBA = 0.005663954884357138 | MOMA = 0.005610697491183548 | proportional change = 0.009402863239726337
# ACGKm | acetylglutamate kinase, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | proportional change = 0.009402863239726337
# ACOTAim | acteylornithine transaminase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | proportional change = 0.009402863239726337
# AGPRim | N-acetyl-g-glutamyl-phosphate reductase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | proportional change = 0.009402863239726337
# CHTNS | chitin synthase | pFBA = 0.005663954884357138 | MOMA = 0.005610697491183548 | proportional change = 0.009402863239726337
# GF6PTA | glutamine-fructose-6-phosphate transaminase | pFBA = 0.005663954884357138 | MOMA = 0.005610697491183548 | proportional change = 0.009402863239726337
# ORNt3m | ornithine mitochondrial transport via proton antiport | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | proportional change = 0.009402863239726337
# ORNTACim | ornithine transacetylase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | proportional change = 0.009402863239726337
# UDPACGLP | UDP-N-acetylglucosamine diphosphorylase | pFBA = 0.005663954884357138 | MOMA = 0.005610697491183548 | proportional change = 0.009402863239726337
# GLYCERIDES | Diglycerides and triglycerides composition (mmol/mmol) | pFBA = 0.002557143764375306 | MOMA = 0.002533099291274566 | proportional change = 0.009402863239726333
# GLCS2 | glycogen synthase (UDPGlc) | pFBA = 0.048875786294769644 | MOMA = 0.048416213960505834 | proportional change = 0.00940286323972633
# TRIGS_PP | triglycerol synthesis | pFBA = 0.0016749291656658256 | MOMA = 0.001659180035784841 | proportional change = 0.009402863239726323
# MIPCS324_SC | mannose-inositol phosphorylceramide synthase (ceramide-3, 24C), yeast-specific | pFBA = 9.081437516498764e-06 | MOMA = 8.996046001511006e-06 | proportional change = 0.009402863239726321
# MI3PP | myo-inositol 3-phosphatase | pFBA = 7.560266571146825e-05 | MOMA = 7.489178418522457e-05 | proportional change = 0.009402863239726321
# MI3PS | 1D-myo-inositol-3-phosphate lyase (isomerizing) | pFBA = 7.560266571146825e-05 | MOMA = 7.489178418522457e-05 | proportional change = 0.009402863239726321
# DNA | DNA composition (mmol/g) - polymerization | pFBA = 8.372438853447358e-05 | MOMA = 8.293713955925422e-05 | proportional change = 0.009402863239726321
# PINOS_PP | phosphatidylinositol synthase, yeast-specific | pFBA = 7.560266571146825e-05 | MOMA = 7.489178418522457e-05 | proportional change = 0.009402863239726321
# IPCavg | Average inositol phosphorylceramide | pFBA = 7.775869095383821e-06 | MOMA = 7.702753661709912e-06 | proportional change = 0.00940286323972632
# MIP2Cavg | Average mannose-(inositol-P)2-ceramide | pFBA = 7.775869095383821e-06 | MOMA = 7.702753661709912e-06 | proportional change = 0.00940286323972632
# MIPCavg | Average mannose-inositol phosphorylceramide | pFBA = 7.775869095383821e-06 | MOMA = 7.702753661709912e-06 | proportional change = 0.00940286323972632
# CARBOHYDRATES | Carbohydrate composition (mmol/g) | pFBA = 0.027629048216376285 | MOMA = 0.027369256054553894 | proportional change = 0.009402863239726318
# DOLPt2er | dolichol phosphate endoplasmic reticular transport via proton symport | pFBA = -0.028457919662867575 | MOMA = -0.028190333736190513 | proportional change = 0.009402863239726314
# MANNANter | mannan endoplasmic reticulum transport via diffusion | pFBA = -0.028457919662867575 | MOMA = -0.028190333736190513 | proportional change = 0.009402863239726314
# dolpmmer | Dolichyl-phosphate-mannose--protein mannosyltransferase, endoplasmic reticular | pFBA = 0.028457919662867575 | MOMA = 0.028190333736190513 | proportional change = 0.009402863239726314
# DOLPMTcer | Dolichyl-phosphate D-mannosyltransferase | pFBA = 0.028457919662867575 | MOMA = 0.028190333736190513 | proportional change = 0.009402863239726314
# HSK | homoserine kinase | pFBA = 0.02112784944667441 | MOMA = 0.020929187167777804 | proportional change = 0.009402863239726276
# THRS | threonine synthase | pFBA = 0.02112784944667441 | MOMA = 0.020929187167777804 | proportional change = 0.009402863239726276
# ASNS1 | asparagine synthase (glutamine-hydrolysing) | pFBA = 0.015958705698556012 | MOMA = 0.01580864817138945 | proportional change = 0.00940286323972627
# RNA | RNA composition (mmol/g) - polymerization | pFBA = 0.004856014534999468 | MOMA = 0.004810354094436745 | proportional change = 0.00940286323972626
# HISTD | histidinol dehydrogenase (step 2) | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# HISTD1 | histidinol dehydrogenase (step 1) | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# ATPPRT | ATP phosphoribosyltransferase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# HISTP | histidinol-phosphatase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# HSTPT | histidinol-phosphate transaminase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# IG3PS | Imidazole-glycerol-3-phosphate synthase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# IGPDH | imidazoleglycerol-phosphate dehydratase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# PRAMPC | phosphoribosyl-AMP cyclohydrolase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# PRATPP | phosphoribosyl-ATP pyrophosphatase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# PRMICIi | 1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase (irreversible) | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | proportional change = 0.009402863239726259
# DESAT182 | Octadecadienoyl-CoA desaturase (n-C18:2CoA -> n-C18:3CoA) | pFBA = 0.0018536213604560807 | MOMA = 0.001836192012305477 | proportional change = 0.009402863239726252
# IPCS326_PP | Inositol phosphorylceramide synthase (ceramide-3, 26C), yeast-specific | pFBA = 8.802283815974484e-06 | MOMA = 8.71951714505562e-06 | proportional change = 0.009402863239726248
# CBPS | carbamoyl-phosphate synthase (glutamine-hydrolysing) | pFBA = 0.032594532389384576 | MOMA = 0.032288050458964365 | proportional change = 0.009402863239726238
# H2Oter | H2O endoplasmic reticulum transport | pFBA = -0.0020862945481351335 | MOMA = -0.0020666774058212324 | proportional change = 0.009402863239726235
# O2ter | O2  transport, endoplasmic reticulum | pFBA = 0.0020862945481351335 | MOMA = 0.0020666774058212324 | proportional change = 0.009402863239726235
# SQ23EPXter | Squalene-2,3-epoxide endoplamic reticular transport | pFBA = 0.0020862945481351335 | MOMA = 0.0020666774058212324 | proportional change = 0.009402863239726235
# Ex_pi | Phosphate exchange | pFBA = -0.016226848177085307 | MOMA = -0.016074269343005924 | proportional change = 0.009402863231002931
# NH4t | ammonia reversible transport | pFBA = 0.6024766465190944 | MOMA = 0.5968131387744922 | proportional change = 0.009400377221796149
# Ex_nh4 | Ammonium exchange | pFBA = -0.6024766465190944 | MOMA = -0.5968131387744922 | proportional change = 0.009400377221796149
# GLUDyi | glutamate dehydrogenase (NADP) | pFBA = 0.4806020169846853 | MOMA = 0.4760846715676176 | proportional change = 0.00939934760451009
# NDPK2 | nucleoside-diphosphate kinase (ATP:UDP) | pFBA = 0.14361272820391288 | MOMA = 0.1422638551288647 | proportional change = 0.009392434026689836
# GALU | UTP-glucose-1-phosphate uridylyltransferase | pFBA = 0.13417370762004716 | MOMA = 0.13291358836466602 | proportional change = 0.00939170033930597
# PGMT | phosphoglucomutase | pFBA = -0.13417370762004716 | MOMA = -0.13291358836466602 | proportional change = 0.00939170033930597
# Ht | H+ diffusion | pFBA = -0.6675096466789585 | MOMA = -0.661256936522401 | proportional change = 0.009367220665149055
# Ex_h | H+ exchange | pFBA = 0.6512827147774847 | MOMA = 0.6451825842422555 | proportional change = 0.009366332618413385
# TRDOXtp | oxidized thioredoxin peroxisomal transport via diffusion | pFBA = 0.0036038540052393342 | MOMA = 0.003570133333171314 | proportional change = 0.0093568363254995
# TRDRDtp | reduced thioredoxin peroxisomal transport via diffusion | pFBA = -0.0036038540052393342 | MOMA = -0.003570133333171314 | proportional change = 0.0093568363254995
# THIORDXp | hydrogen peroxide reductase (thioredoxin), peroxisomal | pFBA = -0.0036038540052393342 | MOMA = -0.003570133333171314 | proportional change = 0.0093568363254995
# METS | methionine synthase | pFBA = 0.005887911178160898 | MOMA = 0.005833873200981695 | proportional change = 0.009177784029697707
# MTHFR3 | 5,10-methylenetetrahydrofolatereductase (NADPH) | pFBA = 0.005887911178160898 | MOMA = 0.005833873200981695 | proportional change = 0.009177784029697707
# ACCOACr | acetyl-CoA carboxylase, reversible reaction | pFBA = 0.06852781887591654 | MOMA = 0.06790575516162707 | proportional change = 0.009077535583262018
# ACOATA | Acetyl-CoA ACP transacylase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS1_4 | Acetyl-[acyl-carrier-protein]:malonyl-[acyl-carrier-protein] | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS1_6 | butyryl-[acyl-carrier protein]:malonyl-[acyl-carrier-protein] | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS1_8 | hexanoyl-[acyl-carrier protein]:malonyl-[acyl-carrier-protein] | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS1_10 | Octanoyl-[acyl-carrier protein]:malonyl-[acyl-carrier-protein] | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS1_12 | Decanoyl-[acyl-carrier protein]:malonyl-[acyl-carrier-protein] | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS2_4 | (3R)-3-Hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS2_6 | (3R)-3-Hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS2_8 | (3R)-3-Hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS2_10 | (3R)-3-Hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS2_12 | (3R)-3-Hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS3_4 | (3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS3_6 | (3R)-3-Hydroxyhexanoyl-[acyl-carrier-protein] hydro-lyase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS3_8 | (3R)-3-Hydroxyoctanoyl-[acyl-carrier-protein] hydro-lyase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS3_10 | (3R)-3-Hydroxydecanoyl-[acyl-carrier-protein] hydro-lyase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS3_12 | (3R)-3-Hydroxydodecanoyl-[acyl-carrier-protein] hydro-lyase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS4_4 | Butyryl-[acyl-carrier protein] reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS4_6 | Hexanoyl-[acyl-carrier protein] reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS4_8 | Octanoyl-[acyl-carrier protein] reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS4_10 | Decanoyl-[acyl-carrier protein] reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS4_12 | Dodecanoyl-[acyl-carrier protein] reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAS5_12 | Dodecanoyl CoA transfarase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAE1_14 | dodecanoyl-CoA:malonyl-CoA C-acyltransferase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAE2_14 | 3-tetradecanoyl-CoA reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAE3_14 | 3-Hydroxytetradecanoyl-CoA dehydrogenase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAE4_14 | (2E)-tetradecanoyl-CoA reductase | pFBA = 0.008734449162752202 | MOMA = 0.008655315867274905 | proportional change = 0.009059906812985878
# FAE1_16 | tetradecanoyl-CoA:malonyl-CoA C-acyltransferase | pFBA = 0.008699802034519378 | MOMA = 0.008620994521250503 | proportional change = 0.00905854098244768
# FAE2_16 | 3-hexadecanoyl-CoA reductase | pFBA = 0.008699802034519378 | MOMA = 0.008620994521250503 | proportional change = 0.00905854098244768
# FAE3_16 | 3-Hydroxyhexadecanoyl-CoA dehydrogenase | pFBA = 0.008699802034519378 | MOMA = 0.008620994521250503 | proportional change = 0.00905854098244768
# FAE4_16 | (2E)-hexadecanoyl-CoA reductase | pFBA = 0.008699802034519378 | MOMA = 0.008620994521250503 | proportional change = 0.00905854098244768
# METAT | methionine adenosyltransferase | pFBA = 0.0030982145521922387 | MOMA = 0.0030704077108673435 | proportional change = 0.008975118041847547
# ADNK1 | adenosine kinase | pFBA = 0.0030982145521922387 | MOMA = 0.003070407710867344 | proportional change = 0.008975118041847406
# AHCi | adenosylhomocysteinase | pFBA = 0.0030982145521922387 | MOMA = 0.003070407710867344 | proportional change = 0.008975118041847406
# H2Otp | H2O transport, peroxisomal | pFBA = -1.1489833899047903 | MOMA = -1.141632176168112 | proportional change = 0.006398015673044146
# NADH2_u6mh | NADH dehydrogenase, mitochondrial | pFBA = 1.1705696486818744 | MOMA = 1.1636271973869317 | proportional change = 0.00593083145694093
# ATPtm_H | ADP/ATP transporter, mitochondrial | pFBA = 8.022674234111067 | MOMA = 8.069311793309772 | proportional change = 0.005813218614861677
# PIt2m | phosphate transporter, mitochondrial | pFBA = 7.99850129685487 | MOMA = 8.043742583561798 | proportional change = 0.005656220462790677
# H2Ot | H2O transport via diffusion | pFBA = -4.7805905360034 | MOMA = -4.799520871640574 | proportional change = 0.003959832053091925
# Ex_h2o | H2O exchange | pFBA = 4.7805905360034 | MOMA = 4.799520871640574 | proportional change = 0.003959832053091925
# FDH | formate dehydrogenase | pFBA = 0.9612962358545989 | MOMA = 0.9590516498002629 | proportional change = 0.002334957706705801
# O2tx | oxygen peroxisomal transport | pFBA = -0.6181980729973803 | MOMA = -0.6182149333334144 | proportional change = 2.7273355855588887e-05
# CATp | catalase | pFBA = 0.6218019270026197 | MOMA = 0.6217850666665856 | proportional change = 2.711528430825502e-05
# DHAK | Dihydroxyacetone kinase | pFBA = 0.22319999999999998 | MOMA = 0.22320000000000004 | proportional change = 2.487058746920154e-16
# DAS | Dihydroxyacetone synthase | pFBA = 0.22319999999999998 | MOMA = 0.22320000000000004 | proportional change = 2.487058746920154e-16
# DHAtx | Dihydroxyacetone peroxisomal transport | pFBA = 0.22319999999999998 | MOMA = 0.22320000000000004 | proportional change = 2.487058746920154e-16
# G3Ptx | Glyceraldehyde 3-phosphate peroxisomal transport | pFBA = 0.22319999999999998 | MOMA = 0.22320000000000004 | proportional change = 2.487058746920154e-16
# XU5Ptx | xylulose-5-phosphate transport | pFBA = 0.22319999999999998 | MOMA = 0.22320000000000004 | proportional change = 2.487058746920154e-16
# GLCt1 | glucose transport (uniport) | pFBA = 0.72 | MOMA = 0.72 | proportional change = 0.0
# FALDH2 | formaldehyde dehydrogenase | pFBA = 1.0168 | MOMA = 1.0168 | proportional change = 0.0
# FALGTHLs | formaldehyde glutathione ligase (spontaneous) | pFBA = 1.0168 | MOMA = 1.0168 | proportional change = 0.0
# METOHte | Methanol extracellular transport | pFBA = -1.24 | MOMA = -1.24 | proportional change = 0.0
# METOHtx | Methanol peroxisomal transport | pFBA = 1.24 | MOMA = 1.24 | proportional change = 0.0
# ATPM | ATP maintenance requirement | pFBA = 1.96 | MOMA = 1.96 | proportional change = 0.0
# SFGTH | S-Formylglutathione hydralase | pFBA = 1.0168 | MOMA = 1.0168 | proportional change = 0.0
# AOD | Alcohol oxidase | pFBA = 1.24 | MOMA = 1.24 | proportional change = 0.0
# FALDtx | formaldehyde peroxisomal transport | pFBA = 1.0168 | MOMA = 1.0168 | proportional change = 0.0
# Ex_glc_D | D-Glucose exchange | pFBA = -0.72 | MOMA = -0.72 | proportional change = 0.0
# Ex_meoh | Methanol exchange | pFBA = -1.24 | MOMA = -1.24 | proportional change = 0.0

# %%
absolute_changes = sorted(
    reaction_changes,
    key=lambda x: x["Absolute change"],
    reverse=True
)

print("Reactions ordered by absolute flux change:\n")

for r in absolute_changes:
    print(
        r["ID"],
        "|", r["Name"],
        "| pFBA =", r["pFBA flux"],
        "| MOMA =", r["MOMA flux"],
        "| absolute change =", r["Absolute change"]
    )
# Out:
# Reactions ordered by absolute flux change:
#
# SUCD3_u6m | succinate dehydrogenase (ubiquinone-6), mitochondrial | pFBA = 0.0 | MOMA = 3.3802230101713437 | absolute change = 3.3802230101713437
# G3PD1ir | glycerol-3-phosphate dehydrogenase (NAD) | pFBA = 0.0032981959043510934 | MOMA = 3.1142647940963757 | absolute change = 3.1109665981920247
# DHAPtm | dihydroxyacetone phosphate transport, mitochondrial | pFBA = 0.0 | MOMA = 3.1025526915334036 | absolute change = 3.1025526915334036
# G3PDm | glycerol-3-phosphate dehydrogenase (FAD), mitochondrial | pFBA = 0.0 | MOMA = 3.1025526915334036 | absolute change = 3.1025526915334036
# GLYC3Ptmc | glycerol-3-phosphate shuttle | pFBA = 9.952817062448541e-06 | MOMA = 3.1025625507654886 | absolute change = 3.102552597948426
# NADH2_u6cm | NADH dehydrogenase, cytosolic/mitochondrial | pFBA = 3.029122511463296 | MOMA = 0.0 | absolute change = 3.029122511463296
# OSUCCCLm | oxalosuccinate carboxy-lyase (2-oxoglutarate-forming) | pFBA = 0.0 | MOMA = 0.3435776222024426 | absolute change = 0.3435776222024426
# ICDOXSUCm | Isocitrate:NADP+ oxidoreductase | pFBA = 0.0 | MOMA = 0.3435776222024426 | absolute change = 0.3435776222024426
# SUCD2_u6m | succinate dehydrogenase (ubiquinone-6), mitochondrial | pFBA = 0.28679931446689166 | MOMA = 0.0 | absolute change = 0.28679931446689166
# ICDHxm | Isocitrate dehydrogenase (NAD+) | pFBA = 0.2798853568467663 | MOMA = 0.0 | absolute change = 0.2798853568467663
# SUCD1m | succinate dehydrogenase | pFBA = 0.0 | MOMA = 0.27767031863794 | absolute change = 0.27767031863794
# AKGMALtp | alpha-ketoglutarate/malate transporter into peroxisomes | pFBA = 0.0 | MOMA = -0.21668886571628754 | absolute change = 0.21668886571628754
# MTHFD | methylenetetrahydrofolate dehydrogenase (NADP) | pFBA = -0.05021557927219475 | MOMA = -0.2186088444384906 | absolute change = 0.16839326516629585
# MALOAAtp | malate/oxaloacetate shuttle | pFBA = 0.08741275608997044 | MOMA = 0.2464129769535105 | absolute change = 0.15900022086354004
# ASPGLUtp | aspartate-glutamate peroxisomal shuttle | pFBA = 0.0 | MOMA = -0.15203607452601778 | absolute change = 0.15203607452601778
# ASPTAp | aspartate transaminase, peroxisomal | pFBA = 0.0 | MOMA = -0.15203607452601778 | absolute change = 0.15203607452601778
# H2Otm | H2O transport, mitochondrial | pFBA = -11.822271600266708 | MOMA = -11.971465355668736 | absolute change = 0.1491937554020275
# ASPTA | aspartate transaminase | pFBA = -0.14092571758987232 | MOMA = 0.0 | absolute change = 0.14092571758987232
# ALATA_L | L-alanine transaminase | pFBA = -0.1007105019233753 | MOMA = 0.0 | absolute change = 0.1007105019233753
# MTHFD2i | methylenetetrahydrofolate dehydrogenase (NAD) | pFBA = 0.0 | MOMA = 0.09015676166331112 | absolute change = 0.09015676166331112
# CO2tm | CO2 transport (diffusion), mitochondrial | pFBA = -1.0682368007884568 | MOMA = -0.9848856622547365 | absolute change = 0.08335113853372034
# GHMT2r | glycine hydroxymethyltransferase, reversible | pFBA = -0.044238840209953875 | MOMA = -0.12253021692656366 | absolute change = 0.07829137671660978
# MTHFC | methenyltetrahydrofolate cyclohydrolase | pFBA = -0.05021557927219475 | MOMA = -0.12845208277517947 | absolute change = 0.07823650350298472
# ATPS3m | ATP synthase, mitochondrial | pFBA = 7.915787564207878 | MOMA = 7.993910543071864 | absolute change = 0.07812297886398678
# ICDHym | Isocitrate dehydrogenase (NADP+) | pFBA = 0.07666304550189824 | MOMA = 0.0 | absolute change = 0.07666304550189824
# GLYtm | glycine passive transport to mitochondria | pFBA = -0.014953911860982272 | MOMA = -0.0907554956423575 | absolute change = 0.07580158378137523
# MTHFCm | methenyltetrahydrifikate cyclohydrolase, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | absolute change = 0.07580157748338344
# 10FTHFtm | 10-Formyltetrahydrofolate mitochondrial transport via diffusion | pFBA = -0.014954581656090538 | MOMA = -0.09075615913947398 | absolute change = 0.07580157748338344
# THFtm | 5,6,7,8-Tetrahydrofolate transport, diffusion, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | absolute change = 0.07580157748338344
# SERtm | L-Serine mitochondrial permease | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | absolute change = 0.07580157748338344
# GHMT2rm | glycine hydroxymethyltransferase, reversible, mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | absolute change = 0.07580157748338344
# MTHFDm | methylenetetrahydrofolate dehydrogenase (NADP), mitochondrial | pFBA = 0.014954581656090538 | MOMA = 0.09075615913947398 | absolute change = 0.07580157748338344
# TYRPYRAT | L-tyrosine:pyruvate aminotransferase | pFBA = 0.0 | MOMA = 0.07312908935112794 | absolute change = 0.07312908935112794
# TYRTAi | tyrosine transaminase, irreversible | pFBA = 0.007753715622177599 | MOMA = 0.08080989784571048 | absolute change = 0.07305618222353288
# GCC2cm | glycine-cleavage complex (lipoamide), mitochondrial | pFBA = 0.6007603739172117 | MOMA = 0.5314230565737523 | absolute change = 0.06933731734345938
# ACONTx | aconitase | pFBA = 0.0 | MOMA = 0.06507357926149698 | absolute change = 0.06507357926149698
# SUCCtp | succinate transporter, peroxisome | pFBA = 0.0 | MOMA = 0.06507357926149698 | absolute change = 0.06507357926149698
# ICLx | Isocitrate lyase | pFBA = 0.0 | MOMA = 0.06507357926149698 | absolute change = 0.06507357926149698
# GLXtp | glyoxylate transport, peroxisomal | pFBA = 0.0 | MOMA = -0.064652791190273 | absolute change = 0.064652791190273
# AKGtp | AKG transporter, peroxisome | pFBA = 0.0 | MOMA = 0.06465279119026976 | absolute change = 0.06465279119026976
# ICL | Isocitrate lyase | pFBA = 0.06247508071856199 | MOMA = 0.0 | absolute change = 0.06247508071856199
# 3MOBtm | 3-methyl-2-oxobutanoate transport, diffusion, mitochondrial | pFBA = -0.020808395350066025 | MOMA = -0.0829312594018384 | absolute change = 0.06212286405177238
# CITtap | citrate/malate antiport into peroxisome | pFBA = 0.08741275608997044 | MOMA = 0.029303323165995737 | absolute change = 0.058109432923974705
# ACONT | aconitase | pFBA = 0.08741275608997039 | MOMA = 0.029303323165997597 | absolute change = 0.05810943292397279
# PDHa1 | pyruvate dehydrogenase (lipoamide) | pFBA = 0.39231212617156597 | MOMA = 0.3345531064119538 | absolute change = 0.057759019759612173
# PDHa2 | pyruvate dehydrogenase (lipoamide) | pFBA = 0.37643547037377373 | MOMA = 0.31882573663733244 | absolute change = 0.05760973373644129
# PDHbrm | pyruvate dehydrogenase (dihydrolipoamide) reversible | pFBA = 0.37643547037377373 | MOMA = 0.31882573663733244 | absolute change = 0.05760973373644129
# G6PDH2 | glucose 6-phosphate dehydrogenase | pFBA = 0.288 | MOMA = 0.34559999999999996 | absolute change = 0.057599999999999985
# GND | phosphogluconate dehydrogenase | pFBA = 0.288 | MOMA = 0.34559999999999996 | absolute change = 0.057599999999999985
# PGL | 6-phosphogluconolactonase | pFBA = 0.288 | MOMA = 0.34559999999999996 | absolute change = 0.057599999999999985
# CYOR_u6m | ubiquinol-6 cytochrome c reductase | pFBA = 4.4941018959432615 | MOMA = 4.5513890691385015 | absolute change = 0.057287173195240015
# GLUK | Glucokinase | pFBA = 0.29714285065348106 | MOMA = 0.2408093962179486 | absolute change = 0.05633345443553245
# G6PI3 | Glucose-6-phosphate isomerase | pFBA = 0.29714285065348106 | MOMA = 0.2408093962179486 | absolute change = 0.05633345443553245
# HEX1 | hexokinase (D-glucose:ATP) | pFBA = 0.4228571493465189 | MOMA = 0.47919060378205136 | absolute change = 0.05633345443553245
# ATPtm_H | ADP/ATP transporter, mitochondrial | pFBA = 8.022674234111067 | MOMA = 8.069311793309772 | absolute change = 0.0466375591987056
# DHAD1 | dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylbutanoate) | pFBA = 0.04607976478531153 | MOMA = 0.0 | absolute change = 0.04607976478531153
# DHAD1m | dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylbutanoate), mitochondrial | pFBA = 0.0 | MOMA = 0.04564648305891651 | absolute change = 0.04564648305891651
# ALDD2y | aldehyde dehydrogenase (acetaldehyde, NADP) | pFBA = 0.22731411681983477 | MOMA = 0.2727769401838017 | absolute change = 0.04546282336396695
# PYRDC | pyruvate decarboxylase | pFBA = 0.22731411681983477 | MOMA = 0.2727767483301682 | absolute change = 0.04546263151033342
# PIt2m | phosphate transporter, mitochondrial | pFBA = 7.99850129685487 | MOMA = 8.043742583561798 | absolute change = 0.045241286706928285
# ADK1 | adenylate kinase | pFBA = 0.29408732978798025 | MOMA = 0.3382550237158348 | absolute change = 0.04416769392785458
# ALATA_Lm | L-alanine transaminase, mitochondrial | pFBA = 0.0 | MOMA = -0.040575380162953936 | absolute change = 0.040575380162953936
# ALAtmi | Alanine transport from mitochondia to cytoplasm | pFBA = 0.0 | MOMA = 0.040575380162953936 | absolute change = 0.040575380162953936
# RPE | ribulose 5-phosphate 3-epimerase | pFBA = 0.24023852556192538 | MOMA = 0.27834341216039105 | absolute change = 0.03810488659846567
# VALTAim | valine transaminase, mitochondiral | pFBA = 0.0 | MOMA = 0.03728477634292189 | absolute change = 0.03728477634292189
# VALt5m | Valine reversible mitochondrial transport | pFBA = 0.0 | MOMA = 0.03728477634292189 | absolute change = 0.03728477634292189
# VALTA | valine transaminase | pFBA = -0.02079964984361927 | MOMA = -0.05788884992362742 | absolute change = 0.03708920008000814
# PPA | inorganic diphosphatase | pFBA = 0.4437645463071106 | MOMA = 0.4756241607434517 | absolute change = 0.03185961443634111
# O2t | o2 transport (diffusion) | pFBA = 2.9071704610978664 | MOMA = 2.9378583354763252 | absolute change = 0.03068787437845888
# Ex_o2 | Oxygen exchange | pFBA = -2.9071704610978664 | MOMA = -2.9378583354763252 | absolute change = 0.03068787437845888
# CO2t | CO2 transporter via diffusion | pFBA = -2.3730677521508166 | MOMA = -2.4029701537829187 | absolute change = 0.029902401632102116
# Ex_co2 | CO2 exchange | pFBA = 2.3730677521508166 | MOMA = 2.4029701537829187 | absolute change = 0.029902401632102116
# CYOOm | cytochrome c oxidase, mitochondrial | pFBA = 2.251116019582741 | MOMA = 2.2788942765464317 | absolute change = 0.02777825696369085
# O2tm | O2 transport (diffusion) | pFBA = 2.251116354480295 | MOMA = 2.2788946082949897 | absolute change = 0.027778253814694676
# ACS | acetyl-CoA synthetase | pFBA = 0.09880287872070526 | MOMA = 0.12569634998938656 | absolute change = 0.0268934712686813
# HSDxi | homoserine dehydrogenase (NADH), irreversible | pFBA = 0.023917629797031603 | MOMA = 0.020929270104917363 | absolute change = 0.0029883596921142404
# MEVK1 | mevalonate kinase (atp) | pFBA = 0.009496410263133283 | MOMA = 0.012400562057764752 | absolute change = 0.002904151794631469
# AKGMALtm | alpha-ketoglutarate/malate transporter | pFBA = 0.10514240932570576 | MOMA = 0.10797289848619968 | absolute change = 0.0028304891604939153
# PPCK | phosphoenolpyruvate carboxykinase | pFBA = 0.048245676546659164 | MOMA = 0.05103916367796499 | absolute change = 0.0027934871313058246
# HSERTAm | homoserine O-trans-acetylase | pFBA = 0.0027897803503571933 | MOMA = 8.293713955925422e-08 | absolute change = 0.002789697413217634
# ACHMStm | O-acetyl-L-homoserine mitochondrial permease | pFBA = -0.0027897803503571933 | MOMA = -8.293713955925422e-08 | absolute change = 0.002789697413217634
# HOMtm | L-homoserine mitochondrial permease | pFBA = -0.0027897803503571933 | MOMA = -8.293713955925422e-08 | absolute change = 0.002789697413217634
# AHSERL2 | O-acetylhomoserine (thiol)-lyase | pFBA = 0.0027896966259686596 | MOMA = 0.0 | absolute change = 0.0027896966259686596
# SHSL1 | O-succinylhomoserine lyase (L-cysteine) | pFBA = 0.0 | MOMA = 0.0027634654901143516 | absolute change = 0.0027634654901143516
# SHSL4r | O-succinylhomoserine lyase (elimination), reversible | pFBA = 0.0 | MOMA = -0.0027634654901143516 | absolute change = 0.0027634654901143516
# CYSTL | cystathionine b-lyase | pFBA = 0.0 | MOMA = 0.0027634654901143516 | absolute change = 0.0027634654901143516
# CYSTH2SS | L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming) | pFBA = 0.0005422373101884111 | MOMA = 0.0033006042170316057 | absolute change = 0.0027583669068431947
# E3MMALOR | (2R,3S)-3-methylmalate:NAD+ oxidoreductase | pFBA = 0.015876655797792228 | MOMA = 0.01849083526473573 | absolute change = 0.0026141794669435024
# CITCONH | (R)-2-Methylmalate hydro-lyase | pFBA = 0.015876655797792228 | MOMA = 0.01849083526473573 | absolute change = 0.0026141794669435024
# E3MMALH | 3-isopropylmalate/(R)-2-methylmalate dehydratase | pFBA = 0.015876655797792228 | MOMA = 0.01849083526473573 | absolute change = 0.0026141794669435024
# CITMALS | D-citramalate synthase | pFBA = 0.015876655797792228 | MOMA = 0.01849083526473573 | absolute change = 0.0026141794669435024
# SUCFUMtm | succinate-fumarate transport, mitochondrial | pFBA = 0.062474410923453724 | MOMA = 0.06507299870152007 | absolute change = 0.002598587778066347
# FDH | formate dehydrogenase | pFBA = 0.9612962358545989 | MOMA = 0.9590516498002629 | absolute change = 0.002244586054335973
# FTHFLi | formate-tetrahydrofolate ligase | pFBA = 0.05758042192097007 | MOMA = 0.05980548144624662 | absolute change = 0.002225059525276546
# AGTi | Alanine glyoxylate aminotransferase (irreversible) | pFBA = 0.06247524816745191 | MOMA = 0.06465295706455215 | absolute change = 0.0021777088971002417
# NADHter | NADH transport into ER | pFBA = 0.0020862945481351335 | MOMA = 0.0 | absolute change = 0.0020862945481351335
# NADter | NAD transport into ER | pFBA = -0.0020862945481351335 | MOMA = 0.0 | absolute change = 0.0020862945481351335
# SQLErx | Squalene epoxidase, endoplasmic reticular (NAD) | pFBA = 0.0020862945481351335 | MOMA = 0.0 | absolute change = 0.0020862945481351335
# SQLEr | Squalene epoxidase, endoplasmic reticular (NADP) | pFBA = 0.0 | MOMA = 0.0020666774058212324 | absolute change = 0.0020666774058212324
# NADPHter | NADPH transport into ER | pFBA = 0.0019321173810279476 | MOMA = 0.003980627351352276 | absolute change = 0.0020485099703243283
# NADPter | NADP transport into ER | pFBA = -0.0019321173810279476 | MOMA = -0.003980627351352276 | absolute change = 0.0020485099703243283
# ACACT1m | acetyl-CoA C-acetyltransferase, mitochondrial | pFBA = 0.012518269635142 | MOMA = 0.010776994742873726 | absolute change = 0.0017412748922682741
# MGSA | methylglyoxal synthase | pFBA = 0.008130143222220276 | MOMA = 0.006399483954361979 | absolute change = 0.001730659267858297
# LGTHL | lactoylglutathione lyase | pFBA = 0.008130143222220276 | MOMA = 0.006399483954361979 | absolute change = 0.001730659267858297
# GLYOX | hydroxyacylglutathione hydrolase | pFBA = 0.008130143222220276 | MOMA = 0.006399483954361979 | absolute change = 0.001730659267858297
# D_LACDcm | D-lactate dehydrogenase, cytosolic/mitochondrial | pFBA = 0.008130143222220276 | MOMA = 0.006399483954361979 | absolute change = 0.001730659267858297
# AACOAT | Acetoacetyl-CoA:acetate CoA-transferase | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# ACACtm | acetoacetate mitochondrial membrane diffusion | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# 34HPPOR | 4-Hydroxyphenylpyruvate:oxygen oxidoreductase | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# FUMAC | fumarylacetoacetase | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# HGNTOR | Homogentisate:oxygen 1,2-oxidoreductase (decyclizing) | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# MACACI | maleylacetoacetate isomerase | pFBA = 0.0 | MOMA = 0.0016235673148910258 | absolute change = 0.0016235673148910258
# PPND2 | prephenate dehydrogenase (NADP) | pFBA = 0.007753715622177599 | MOMA = 0.009304458746613118 | absolute change = 0.0015507431244355194
# CHORM | chorismate mutase | pFBA = 0.019035576977197915 | MOMA = 0.020480238302222627 | absolute change = 0.0014446613250247119
# DDPAm | 2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase, mitochondrial | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# E4Ptm | D-erythrose 4-phosphate mtiochondrial transport via diffusion | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# 2DDA7Ptm | 2-Dehydro-3-deoxy-D-arabino-heptonate7-phohsphate mitochondrial transport via diffusion | pFBA = -0.024122838273329582 | MOMA = -0.025519581838982494 | absolute change = 0.0013967435656529123
# CITtbm | citrate transport, mitochondrial | pFBA = -0.024122838273329582 | MOMA = -0.025519581838982494 | absolute change = 0.0013967435656529123
# CHORS | chorismate synthase | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# DHQS | 3-dehydroquinate synthase | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# DHQTi | 3-dehydroquinate dehydratase, irreversible | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# PSCVTi | 3-phosphoshikimate 1-carboxyvinyltransferase, irreversible | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# SHK3D | shikimate dehydrogenase | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# SHKK | shikimate kinase | pFBA = 0.024122838273329582 | MOMA = 0.025519581838982494 | absolute change = 0.0013967435656529123
# NDPK2 | nucleoside-diphosphate kinase (ATP:UDP) | pFBA = 0.14361272820391288 | MOMA = 0.1422638551288647 | absolute change = 0.0013488730750481903
# GALU | UTP-glucose-1-phosphate uridylyltransferase | pFBA = 0.13417370762004716 | MOMA = 0.13291358836466602 | absolute change = 0.001260119255381137
# PGMT | phosphoglucomutase | pFBA = -0.13417370762004716 | MOMA = -0.13291358836466602 | absolute change = 0.001260119255381137
# GLNS | glutamine synthetase | pFBA = 0.1180441047999352 | MOMA = 0.1169341522262489 | absolute change = 0.0011099525736863042
# 13GS | 1,3-beta-glucan synthase | pFBA = 0.08468303278319331 | MOMA = 0.08388676980720768 | absolute change = 0.0007962629759856316
# growth | Growth | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | absolute change = 0.0007872489752193679
# COF | Cofactor composition (mmol/g DCW) | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | absolute change = 0.0007872489752193679
# Ex_biomass | Biomass exchange | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | absolute change = 0.0007872489752193679
# biomass_glc_meoh_60/40 | Biomass composition (g/g) - 60/40 Glucose/Methanol | pFBA = 0.08372438853447359 | MOMA = 0.08293713955925422 | absolute change = 0.0007872489752193679
# ACCOACr | acetyl-CoA carboxylase, reversible reaction | pFBA = 0.06852781887591654 | MOMA = 0.06790575516162707 | absolute change = 0.0006220637142894669
# GLCS2 | glycogen synthase (UDPGlc) | pFBA = 0.048875786294769644 | MOMA = 0.048416213960505834 | absolute change = 0.00045957233426380945
# ACLSm | acetolactate synthase, mitochondrial | pFBA = 0.04607976478531153 | MOMA = 0.04564648305891651 | absolute change = 0.00043328172639502116
# KARA1im | acetohydroxy acid isomeroreductase, mitochondrial | pFBA = 0.04607976478531153 | MOMA = 0.04564648305891651 | absolute change = 0.00043328172639502116
# MALSp | malate synthase | pFBA = 0.0 | MOMA = 0.00042078807122396256 | absolute change = 0.00042078807122396256
# PROTEINS | Aminoacid composition mmol/g) | pFBA = 0.04102495038189206 | MOMA = 0.04063919838403457 | absolute change = 0.00038575199785748776
# CBPS | carbamoyl-phosphate synthase (glutamine-hydrolysing) | pFBA = 0.032594532389384576 | MOMA = 0.032288050458964365 | absolute change = 0.00030648193042021044
# ACGKm | acetylglutamate kinase, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | absolute change = 0.00027889869445096513
# ACOTAim | acteylornithine transaminase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | absolute change = 0.00027889869445096513
# AGPRim | N-acetyl-g-glutamyl-phosphate reductase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | absolute change = 0.00027889869445096513
# ORNt3m | ornithine mitochondrial transport via proton antiport | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | absolute change = 0.00027889869445096513
# ORNTACim | ornithine transacetylase, irreversible, mitochondrial | pFBA = 0.029661039126107958 | MOMA = 0.029382140431656992 | absolute change = 0.00027889869445096513
# MAN1PT2 | mannose-1-phosphate guanylyltransferase (GDP) | pFBA = 0.028473471401058343 | MOMA = 0.02820573924351393 | absolute change = 0.0002677321575444147
# MAN6PI | mannose-6-phosphate isomerase | pFBA = -0.028473471401058343 | MOMA = -0.02820573924351393 | absolute change = 0.0002677321575444147
# PMANM | phosphomannomutase | pFBA = -0.028473471401058343 | MOMA = -0.02820573924351393 | absolute change = 0.0002677321575444147
# DOLPt2er | dolichol phosphate endoplasmic reticular transport via proton symport | pFBA = -0.028457919662867575 | MOMA = -0.028190333736190513 | absolute change = 0.0002675859266770622
# MANNANter | mannan endoplasmic reticulum transport via diffusion | pFBA = -0.028457919662867575 | MOMA = -0.028190333736190513 | absolute change = 0.0002675859266770622
# dolpmmer | Dolichyl-phosphate-mannose--protein mannosyltransferase, endoplasmic reticular | pFBA = 0.028457919662867575 | MOMA = 0.028190333736190513 | absolute change = 0.0002675859266770622
# DOLPMTcer | Dolichyl-phosphate D-mannosyltransferase | pFBA = 0.028457919662867575 | MOMA = 0.028190333736190513 | absolute change = 0.0002675859266770622
# CARBOHYDRATES | Carbohydrate composition (mmol/g) | pFBA = 0.027629048216376285 | MOMA = 0.027369256054553894 | absolute change = 0.00025979216182239057
# PRPPS | phosphoribosylpyrophosphate synthetase | pFBA = 0.027180373898504487 | MOMA = 0.026924800559933904 | absolute change = 0.0002555733385705833
# 3C4MOPtm | 3-Carboxy-4-methyl-2-oxopentanoate transport, diffusion, mitochondrial | pFBA = 0.025271369435245508 | MOMA = 0.025033746204565294 | absolute change = 0.00023762323068021382
# OMCDCm | 2-oxo-4-methyl-3-carboxypentanoate decarboxylation | pFBA = 0.025271369435245508 | MOMA = 0.025033746204565294 | absolute change = 0.00023762323068021382
# 4MOPtm | 4-Methyl-2-oxopentanoate transport into mitochondria | pFBA = -0.025271369435245508 | MOMA = -0.025033746204565294 | absolute change = 0.00023762323068021382
# DHORD4i | dihydoorotic acid (ubiquinone-6), irreversible | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | absolute change = 7.155896372500539e-05
# ASPCT | aspartate carbamoyltransferase | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | absolute change = 7.155896372500539e-05
# DHORTS | dihydroorotase | pFBA = -0.007610337606812317 | MOMA = -0.007538778643087312 | absolute change = 7.155896372500539e-05
# OMPDC | orotidine-5'-phosphate decarboxylase | pFBA = 0.007610337606812317 | MOMA = 0.007538778643087312 | absolute change = 7.155896372500539e-05
# ORPT | orotate phosphoribosyltransferase | pFBA = -0.007610337606812317 | MOMA = -0.007538778643087312 | absolute change = 7.155896372500539e-05
# FCYTB5R | NADH:ferricytochrome-b5 oxidoreductase | pFBA = 0.0068254842618663165 | MOMA = 0.006761305166807084 | absolute change = 6.417909505923233e-05
# FCYTDESAT18 | steroyl-CoA,hydrogen-donor:oxygen oxidoreductase | pFBA = 0.0068254842618663165 | MOMA = 0.006761305166807084 | absolute change = 6.417909505923233e-05
# HISTD | histidinol dehydrogenase (step 2) | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | absolute change = 6.249182365291282e-05
# HISTD1 | histidinol dehydrogenase (step 1) | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | absolute change = 6.249182365291282e-05
# ATPPRT | ATP phosphoribosyltransferase | pFBA = 0.006646041961866514 | MOMA = 0.006583550138213601 | absolute change = 6.249182365291282e-05
# ...
# Ex_4abz | 4-Aminobenzoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_5aop | 5-Aminolevulinate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_8aonn | 8-Amino-7-oxononanoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_abt | L-Arabinitol exchange | pFBA = -0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_4abut | 4-Aminobutanoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_acald | Acetaldehyde exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_aces | ethylacetate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ACP | acyl carrier protein exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ade | Adenine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_adn | Adenosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_mal_L | L-Malate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_akg | 2-Oxoglutarate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ala_D | D-Alanine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ala_L | L-Alanine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_alltt | Allantoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_amet | S-Adenosyl-L-methionine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_arab_D | D-Arabinose exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_arab_L | L-Arabinose exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_arg_L | L-Arginine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_btd_RR | BDOH exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_chol | Choline exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_cit | Citrate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_crn | Carnitine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_csn | Cytosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_cys_L | L-Cysteine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_cytd | Cytidine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_dad_2 | Deoxyadenosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_dann | 7,8-Diaminononanoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_dcyt | Deoxycytidine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_dgsn | Deoxyguanosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_din | Deoxyinosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_dttp | dTTP exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_duri | Deoxyuridine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_etha | Ethanolamine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_fru | D-Fructose exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_fum | Fumarate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gal | D-Galactose exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gam6p | D-Glucosamine 6-phosphate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gcald | Glycolaldehyde exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gln_L | L-Glutamine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_glu_L | L-Glutamate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_glx | Glyoxylate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gly | Glycine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gsn | Guanosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gthox | Oxidized glutathione exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gthrd | Reduced glutathione exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_gua | Guanine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_hdca | Hexadecanoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_hdcea | Hexadecenoate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_his_L | L-Histidine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_hxan | Hypoxanthine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_iamac | Isoamyl acetate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_iamoh | Isoamyl alcohol exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ibutac | isobutyl acetate exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ibutoh | Isobutyl alcohol exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_id3acald | Indole-3-acetaldehyde exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ile_L | L-Isoleucine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ind3eth | Indole-3-ethanol exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_ins | Inosine exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex
| pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# BIOMASS4060b | Biomass composition 40:60 (g/g) | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# rolAA | ROL protein | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# rolRNA | ROL RNA mmol/g | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# rolDNA | ROL DNA mmol/g | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# pROL | total ROL g/g fab | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# ROLt | ROL transport | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_rol | rol exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA200COAabcp | peroxisomal transport of eicosanoyl-CoA | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA220COAabcp | peroxisomal transport of docosanoyl-CoA | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# H2Otg | Water transport into golgi | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RMNt | L-rhamnose transport | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RMNDH | L-rhamnose dehydrogenase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RHAMLAC | L-rhamnonic acid lactonase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RHAMDH | L-rhamnonate dehydratase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# KDRALD | 2-keto-3-deoxy-L-rhamnonate aldolase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# Ex_rmn | L-rhamnose exchange | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# DHAKx | Dihydroxyacetone kinase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FBAx | fructose-bisphosphate aldolase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FBPx | fructose-bisphosphatase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# TKT2x | transketolase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FBA3x | Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# SHBPH | Sedoheptulose bisphosphatase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# TKT1x | transketolase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RPIx | ribose-5-phosphate isomerase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# RPEx | ribulose 5-phosphate 3-epimerase | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# DHAPtx | Dihydroxyacetone phosphate transport from peroxisomes | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA140tpc | Tetradecanoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA141tpc | Tetradecenoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA160tpc | Hexadecanoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA161tpc | Hexadecenoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA180tpc | Octadecanoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA181tpc | Octadecenoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA182tpc | Octadecadienoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA183tpc | Octadecadienoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# FA260tpc | Hexacosanoate transport out of peroxisome | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# LIPIDS_glyc | Lipid composition (mmol/g)- Glycerol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# PROTEINS_glyc | Aminoacid composition (mmol/g) - Glycerol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# STEROLS_glyc | Sterol composition (mmol/mmol)- Glycerol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# BIOMASS_glyc | Biomass composition (g/g)- Glycerol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# LIPIDS_meoh | Lipid composition (mmol/g)- Methanol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# PROTEINS_meoh | Aminoacid composition (mmol/g) - Methanol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# STEROLS_meoh | Sterol composition (mmol/mmol)- Methanol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0
# BIOMASS_meoh | Biomass composition (g/g)- Methanol | pFBA = 0.0 | MOMA = 0.0 | absolute change = 0.0

# %% [markdown]
# # Version with Randomness

# %%
increase_min = 0.05   # 5%
increase_max = 0.10   # 10%

flux_threshold = 1e-6

# Increase NADPH-producing reactions + MOMA

nadph_c = model.metabolites.get_by_id("nadph_c")

with model:

    # Identify NADPH-producing reactions
    nadph_producing_reactions = []

    for reaction in model.reactions:

        nadph_stoich = reaction.metabolites.get(nadph_c, 0)
        reference_flux = pfba_WT.fluxes[reaction.id]

        # Only reactions that actually produce NADPH
        # in the pFBA_WT solution
        if reference_flux * nadph_stoich > 0:

            # Random increase between 5 and 20%
            increase = np.random.uniform(
                increase_min,
                increase_max
            )

            target_flux = reference_flux * (1 + increase)

            nadph_producing_reactions.append({
                "ID": reaction.id,
                "Name": reaction.name,
                "Reference flux": reference_flux,
                "NADPH stoichiometry": nadph_stoich,
                "Increase": increase,
                "Target flux": target_flux
            })

            # Set new lower bound
            reaction.lower_bound = target_flux

    moma_result = cobra.flux_analysis.moma(
        model,
        solution=pfba_WT,
        linear=True
    )
    
# Calculate flux changes

reaction_changes = []

for reaction in model.reactions:

    reaction_id = reaction.id

    reference_flux = pfba_WT.fluxes[reaction_id]
    moma_flux = moma_result.fluxes[reaction_id]

    absolute_change = abs(
        moma_flux - reference_flux
    )

    # Avoid division by zero 
    if abs(reference_flux) > flux_threshold:

        proportional_change = (
            absolute_change / abs(reference_flux)
        )

    else:

        proportional_change = np.nan

    reaction_changes.append({
        "ID": reaction_id,
        "Name": reaction.name,
        "pFBA flux": reference_flux,
        "MOMA flux": moma_flux,
        "Absolute change": absolute_change,
        "Proportional change": proportional_change
    })

# Top 10 proportional changes


proportional_changes = sorted(
    [
        r for r in reaction_changes
        if abs(r["pFBA flux"]) > flux_threshold
    ],
    key=lambda x: x["Proportional change"],
    reverse=True
)

print("\n===== TOP 10 PROPORTIONAL CHANGES =====\n")

for r in proportional_changes[:10]:

    print(
        r["ID"],
        "|", r["Name"],
        "| pFBA =", round(r["pFBA flux"], 6),
        "| MOMA =", round(r["MOMA flux"], 6),
        "| change =",
        round(r["Proportional change"] * 100, 2),
        "%"
    )

# Top 10 absolute changes

absolute_changes = sorted(
    reaction_changes,
    key=lambda x: x["Absolute change"],
    reverse=True
)

print("\n===== TOP 10 ABSOLUTE CHANGES =====\n")

for r in absolute_changes[:10]:

    print(
        r["ID"],
        "|", r["Name"],
        "| pFBA =", round(r["pFBA flux"], 6),
        "| MOMA =", round(r["MOMA flux"], 6),
        "| absolute change =",
        round(r["Absolute change"], 6)
    )

# Save reaction IDs to Excel

proportional_ids = [
    r["ID"] for r in proportional_changes[:10]
]

absolute_ids = [
    r["ID"] for r in absolute_changes[:10]
]

with pd.ExcelWriter(
    "RDXMAX_it.xlsx",
    engine="openpyxl"
) as writer:

    pd.DataFrame({
        "Reaction ID": proportional_ids
    }).to_excel(
        writer,
        sheet_name="Top 10 Proportional",
        index=False
    )

    pd.DataFrame({
        "Reaction ID": absolute_ids
    }).to_excel(
        writer,
        sheet_name="Top 10 Absolute",
        index=False
    )

print("\nResults saved to RDXMAX_it.xlsx")
# Out:
# ===== TOP 10 PROPORTIONAL CHANGES =====
#
# GLCCERS18m9 | Glucoceramide synthase (C18OH:2:9m) | pFBA = 4e-06 | MOMA = 0.007806 | change = 184011.17 %
# CER9MET18 | Ceramide C9 methylase (C18OH:2) | pFBA = 4e-06 | MOMA = 0.007806 | change = 184011.17 %
# CER8DS2d18 | Ceramide delta-8 desaturase (C18OH:1) | pFBA = 6e-06 | MOMA = 0.007807 | change = 132400.76 %
# CER4DS2d18 | Ceramide delta-4 desaturase (C18OH) | pFBA = 6e-06 | MOMA = 0.007808 | change = 123270.32 %
# CERS2d18 | Ceramide-2' synthase (18C) | pFBA = 6e-06 | MOMA = 0.007808 | change = 120310.0 %
# CERS118 | Ceramide-1 synthase (18C) | pFBA = 8e-06 | MOMA = 0.007809 | change = 100024.81 %
# ASP1DC | aspartate 1-decarboxylase | pFBA = 9e-06 | MOMA = 0.007825 | change = 89373.03 %
# PAtm_PP | phosphatidate reversible transport, mitochondrial, yeast-specific | pFBA = 2e-05 | MOMA = 0.008516 | change = 42682.97 %
# DASYNm_PP | CDP-Diacylglycerol synthetase, yeast-specific, mitochondrial | pFBA = 2e-05 | MOMA = 0.008516 | change = 42682.97 %
# CTPtm | CTP/CMP antiport | pFBA = 2e-05 | MOMA = 0.008516 | change = 42682.97 %
#
# ===== TOP 10 ABSOLUTE CHANGES =====
#
# Ex_glc_D | D-Glucose exchange | pFBA = -0.72 | MOMA = -0.768965 | absolute change = 0.048965
# PGI | glucose-6-phosphate isomerase | pFBA = 0.0 | MOMA = -0.033535 | absolute change = 0.033535
# TYRTAi | tyrosine transaminase, irreversible | pFBA = 0.007754 | MOMA = 0.033734 | absolute change = 0.02598
# TREHe | alpha,alpha-trehalase, extracellular | pFBA = 0.0 | MOMA = -0.024483 | absolute change = 0.024483
# H2Ot | H2O transport via diffusion | pFBA = -4.780591 | MOMA = -4.75744 | absolute change = 0.023151
# RPE | ribulose 5-phosphate 3-epimerase | pFBA = 0.240239 | MOMA = 0.260678 | absolute change = 0.020439
# ETHAMPPL | ethanolamine-phosphate phosphate-lyase | pFBA = 0.0 | MOMA = 0.019934 | absolute change = 0.019934
# G6PDH2 | glucose 6-phosphate dehydrogenase | pFBA = 0.288 | MOMA = 0.307586 | absolute change = 0.019586
# GND | phosphogluconate dehydrogenase | pFBA = 0.288 | MOMA = 0.307586 | absolute change = 0.019586
# PGL | 6-phosphogluconolactonase | pFBA = 0.288 | MOMA = 0.307586 | absolute change = 0.019586
#
# Results saved to RDXMAX_it.xlsx

# %%
moma_result.fluxes['Ex_biomass']
# Out:
# 0.08412197322606063

# %%
# NADPH turnover rate WT strain

positive_nadph_flux_sum_WT = 0.0
for reaction in nadph_c.reactions:
    flux = pfba_WT.fluxes[reaction.id]
    coef = reaction.get_coefficient(nadph_c)
    # No totes les reaccions tenen 1 de coeficient estequiomètric pel cofactor
    #independentment si s'està produint o consumint
    positive_nadph_flux_sum_WT += abs(flux*coef)
    

print (positive_nadph_flux_sum_WT/2)
# Out:
# 0.8110824650290331

# %%
# NADPH turnover rate mutant strain

positive_nadph_flux_sum_moma = 0.0
for reaction in nadph_c.reactions:
    flux = moma_result.fluxes[reaction.id]
    coef = reaction.get_coefficient(nadph_c)
    # No totes les reaccions tenen 1 de coeficient estequiomètric pel cofactor
    #independentment si s'està produint o consumint
    positive_nadph_flux_sum_moma += abs(flux*coef)
    

print (positive_nadph_flux_sum_moma/2)
# Out:
# 0.9247359615533146

# %%
#Set the number of iterations to run

n_iterations = 20

proportional_results = []
absolute_results = []

for iteration in range(1, n_iterations + 1):

    # 1. Randomly increase each NADPH-producing reaction between a 5 and 10 %

    increase_min = 0.05
    increase_max = 0.10

    nadph_c = model.metabolites.get_by_id("nadph_c")

    with model:

        for reaction in model.reactions:

            nadph_stoich = reaction.metabolites.get(nadph_c, 0)
            reference_flux = pfba_WT.fluxes[reaction.id]

            if reference_flux * nadph_stoich > 0:

                increase = np.random.uniform(
                    increase_min,
                    increase_max
                )

                target_flux = reference_flux * (1 + increase)

                reaction.lower_bound = target_flux
       
        # 2. MOMA using pFBA_WT as reference
    
        moma_result = cobra.flux_analysis.moma(
            model,
            solution=pfba_WT,
            linear=True
        )

        # 3. Calculate changes

        reaction_changes = []

        for reaction in model.reactions:

            reaction_id = reaction.id

            reference_flux = pfba_WT.fluxes[reaction_id]
            moma_flux = moma_result.fluxes[reaction_id]

            absolute_change = abs(
                moma_flux - reference_flux
            )

            if abs(reference_flux) > 1e-6:

                proportional_change = (
                    absolute_change / abs(reference_flux)
                )

            else:

                proportional_change = np.nan

            reaction_changes.append({
                "ID": reaction_id,
                "Name": reaction.name,
                "pFBA flux": reference_flux,
                "MOMA flux": moma_flux,
                "Absolute change": absolute_change,
                "Proportional change": proportional_change
            })

        # 4. Top 10 proportional changes

        proportional_changes = sorted(
            [
                r for r in reaction_changes
                if not np.isnan(r["Proportional change"])
            ],
            key=lambda x: x["Proportional change"],
            reverse=True
        )

        # Use reaction IDs instead of names
        proportional_ids = [
            r["ID"] for r in proportional_changes[:10]
        ]

        # 5. Top 10 absolute changes

        absolute_changes = sorted(
            reaction_changes,
            key=lambda x: x["Absolute change"],
            reverse=True
        )

        # Use reaction IDs instead of names
        absolute_ids = [
            r["ID"] for r in absolute_changes[:10]
        ]

    # 6. Store results from this iteration

    proportional_results.append(
        [iteration] + proportional_ids
    )

    absolute_results.append(
        [iteration] + absolute_ids
    )

    print(f"Iteration {iteration}/{n_iterations} completed")

# 7. Create Excel file

columns = ["Iteration"] + [
    f"Top {i}" for i in range(1, 11)
]

df_proportional = pd.DataFrame(
    proportional_results,
    columns=columns
)

df_absolute = pd.DataFrame(
    absolute_results,
    columns=columns
)


with pd.ExcelWriter(
    "RDXMAX_results.xlsx",
    engine="openpyxl"
) as writer:

    df_proportional.to_excel(
        writer,
        sheet_name="Proportional changes",
        index=False
    )

    df_absolute.to_excel(
        writer,
        sheet_name="Absolute changes",
        index=False
    )

print("Excel file created: RDXMAX_results.xlsx")
# Out:
# Iteration 1/20 completed
# Iteration 2/20 completed
# Iteration 3/20 completed
# Iteration 4/20 completed
# Iteration 5/20 completed
# Iteration 6/20 completed
# Iteration 7/20 completed
# Iteration 8/20 completed
# Iteration 9/20 completed
# Iteration 10/20 completed
# Iteration 11/20 completed
# Iteration 12/20 completed
# Iteration 13/20 completed
# Iteration 14/20 completed
# Iteration 15/20 completed
# Iteration 16/20 completed
# Iteration 17/20 completed
# Iteration 18/20 completed
# Iteration 19/20 completed
# Iteration 20/20 completed
# Excel file created: RDXMAX_results.xlsx

# %% [markdown]
# ### The next step is to count the number of times that reactions appear in the lists

# %%
from collections import Counter

# Remove the Iteration column
proportional_ids = df_proportional.drop(columns=["Iteration"]).values.flatten()
absolute_ids = df_absolute.drop(columns=["Iteration"]).values.flatten()

# Count occurrences
proportional_counts = Counter(proportional_ids)
absolute_counts = Counter(absolute_ids)

# Convert to DataFrames and sort
df_proportional_counts = pd.DataFrame(
    proportional_counts.items(),
    columns=["Reaction ID", "Occurrences"]
).sort_values(
    "Occurrences",
    ascending=False
)

df_absolute_counts = pd.DataFrame(
    absolute_counts.items(),
    columns=["Reaction ID", "Occurrences"]
).sort_values(
    "Occurrences",
    ascending=False
)

print("\n===== PROPORTIONAL CHANGE FREQUENCY =====\n")
print(df_proportional_counts)

print("\n===== ABSOLUTE CHANGE FREQUENCY =====\n")
print(df_absolute_counts)
# Out:
# ===== PROPORTIONAL CHANGE FREQUENCY =====
#
#    Reaction ID  Occurrences
# 15     GHMT2rm           17
# 12      MTHFCm           17
# 17       THFtm           17
# 14       SERtm           17
# 13    10FTHFtm           17
# 11       GLYtm           17
# 16      MTHFDm           16
# 2        RNDR1           10
# 20    CYSTH2SS            7
# 19       VALTA            7
# 4   2OXOADPtim            6
# 3       OAAt2m            5
# 1        MEVK2            4
# 22   GLYC3Ptmc            4
# 5         GLUK            4
# 23     G3PD1ir            4
# 9      D_LACtm            4
# 10      3MOBtm            3
# 25        TKT2            3
# 8       ASPt2m            3
# 24      PHETA1            3
# 26      GLUt7m            2
# 27      GCC2cm            2
# 0        PUTA3            2
# 21      TYRTAi            2
# 6        G6PI3            2
# 29      GHMT2r            2
# 18       IPPSm            1
# 7     MALOAAtp            1
# 28         GK2            1
#
# ===== ABSOLUTE CHANGE FREQUENCY =====
#
#    Reaction ID  Occurrences
# 0         GLUK           12
# 2         HEX1           10
# 21       PDHcm            9
# 20      GCC2cm            9
# 4     OSUCCCLm            8
# 10   SUCD3_u6m            8
# 5    ICDOXSUCm            7
# 6       ICDHxm            7
# 22     ALATA_L            7
# 3          PGI            6
# 1        G6PI3            6
# 13       H2Otm            5
# 28        G6PI            5
# 25      ICDHym            5
# 7        ASPTA            5
# 8     ASPGLUtp            5
# 12   SUCD2_u6m            5
# 11      SUCD1m            5
# 9       ASPTAp            5
# 35   GLYC3Ptmc            4
# 34       G3PDm            4
# 33      DHAPtm            4
# 31     G3PD1ir            4
# 30    AKGMALtp            4
# 32  NADH2_u6cm            4
# 24       VPAMT            4
# 23       VALTA            4
# 29    MALOAAtp            3
# 43       MTHFD            3
# 41      GHMT2r            3
# 42       MTHFC            3
# 44       GLYtm            3
# 16     ATPtm_H            2
# 36      CITtap            2
# 37       AKGtp            2
# 38       CITtp            2
# 39       ADPtn            2
# 40       ATPtn            2
# 46     PYR5CDm            1
# 45      MTHFCm            1
# 48    PHEPYRAT            1
# 47       PUTA3            1
# 14       DHAD1            1
# 15      DHAD1m            1
# 27      TYRTAi            1
# 26    TYRPYRAT            1
# 19       IPPSm            1
# 18       PIt2m            1
# 17      3MOBtm            1
# 49      PHETA1            1

# %%
# Transfer the results into an Excel file
with pd.ExcelWriter(
    "RDXMAX_frecuencies.xlsx",
    engine="openpyxl"
) as writer:

    df_proportional.to_excel(
        writer,
        sheet_name="Proportional changes",
        index=False
    )

    df_absolute.to_excel(
        writer,
        sheet_name="Absolute changes",
        index=False
    )

    df_proportional_counts.to_excel(
        writer,
        sheet_name="Proportional frequency",
        index=False
    )

    df_absolute_counts.to_excel(
        writer,
        sheet_name="Absolute frequency",
        index=False
    )
